# %%
import os
import glob
import torch
import random
import numpy as np
import pandas as pd
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader, random_split
from torch.nn.utils.rnn import pad_sequence

# Set environment variables to avoid library conflicts and configure CUDA
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # 数据预处理

# %%
# Function to check if a file corresponds to the left side ("L")
def is_left_file(filename):
    return os.path.basename(filename).startswith("L")

# Function to find columns with all zeros in trajectory CSV files within a folder
def find_all_zero_columns(folder):
    files = glob.glob(os.path.join(folder, '*_trajectory.csv'))
    all_zero_cols = set()

    for file in files:
        is_left = is_left_file(file) # Check if the file is for the left side
        prefix = 'L' if is_left else 'R' # Prefix for columns based on side (L or R)

        df = pd.read_csv(file)
        relevant_cols = [col for col in df.columns if col.startswith(prefix)]

        df_subset = df[relevant_cols]
        zero_cols = df_subset.columns[(df_subset == 0).all()].tolist()
        all_zero_cols.update(zero_cols)

    return all_zero_cols

# Identify markers with all-zero values across training and validation datasets and merge results
train_zero_cols = find_all_zero_columns('random_dataset/train')
val_zero_cols = find_all_zero_columns('random_dataset/val')
merged_zero_cols = sorted(train_zero_cols.union(val_zero_cols))

print("Markers with all zero:")
print(', '.join(merged_zero_cols))

# remove L(R)KNM, L(R)MED, L(R)SHO, L(R)SMH
# Out:
# Markers with all zero:
# LKNM_X, LKNM_X', LKNM_X'', LKNM_Y, LKNM_Y', LKNM_Y'', LKNM_Z, LKNM_Z', LKNM_Z'', LMED_X, LMED_X', LMED_X'', LMED_Y, LMED_Y', LMED_Y'', LMED_Z, LMED_Z', LMED_Z'', LSMH_X, LSMH_X', LSMH_X'', LSMH_Y, LSMH_Y', LSMH_Y'', LSMH_Z, LSMH_Z', LSMH_Z'', RKNM_X, RKNM_X', RKNM_X'', RKNM_Y, RKNM_Y', RKNM_Y'', RKNM_Z, RKNM_Z', RKNM_Z'', RMED_X, RMED_X', RMED_X'', RMED_Y, RMED_Y', RMED_Y'', RMED_Z, RMED_Z', RMED_Z'', RSHO_X, RSHO_X', RSHO_X'', RSHO_Y, RSHO_Y', RSHO_Y'', RSHO_Z, RSHO_Z', RSHO_Z'', RSMH_X, RSMH_X', RSMH_X'', RSMH_Y, RSMH_Y', RSMH_Y'', RSMH_Z, RSMH_Z', RSMH_Z''

# %%
# ========== Data Loading Functions ==========

# Define excluded and fixed marker points for trajectory processing
EXCLUDED_POINTS = ['LFHD', 'RFHD', 'LBHD', 'RBHD', 'C7', 'T10', 'CLAV', 'RBAK'] # Markers to exclude
NUM_FEATURES = 9 # Number of features per marker (position, velocity, acceleration in 3D)
FIXED_POINTS = ['LANK', 'LHEE', 'LKNE', 'LTOE', 'LTHI', 'LTIAD', 'LTIAP', 'LTIB', 'LTHAD', 'LTHAP', 'LPSI', 'LASI', 'LFMH', 'LVMH', 
                'RANK', 'RHEE', 'RKNE', 'RTOE', 'RTHI', 'RTIAD', 'RTIAP', 'RTIB', 'RTHAD', 'RTHAP', 'RPSI', 'RASI', 'RFMH', 'RVMH'] # Fixed marker points for left (L) and right (R) sides

def is_left_file(filename):
    return os.path.basename(filename).startswith("L")

# Function to pair trajectory and model files based on matching filenames
def pair_files(folder_path):
    traj_files = sorted(glob.glob(os.path.join(folder_path, '*_trajectory.csv')))
    model_files = sorted(glob.glob(os.path.join(folder_path, '*_model.csv')))
    pairs = []
    for traj in traj_files:
        base = os.path.basename(traj).replace('_trajectory.csv', '')
        model = os.path.join(folder_path, base + '_model.csv')
        if os.path.exists(model):
            pairs.append((traj, model))
    return pairs

# Function to read trajectory data from a CSV file and format it into tensors
def read_trajectory(traj_path, is_left, selected_markers=None):
    df = pd.read_csv(traj_path)
    suffixes = ['X', 'Y', 'Z', "X'", "Y'", "Z'", "X''", "Y''", "Z''"] # Suffixes for marker features
    prefix = 'L' if is_left else 'R' # Prefix for left or right side

    if selected_markers is not None:
        point_list = [f"{prefix}{m}" for m in selected_markers] # Prefix selected markers
    else:
        point_list = [p for p in FIXED_POINTS if p.startswith(prefix)] # Use fixed points for the side

    # Select relevant columns and reshape data for model input
    cols = [f"{p}_{s}" for p in point_list for s in suffixes if f"{p}_{s}" in df.columns]
    X = df[cols].values.reshape(-1, len(point_list), NUM_FEATURES) # Reshape to (T, N, D)
    return X

# Function to read Knee Adduction Moment (KAM) values from model file
def read_kam(model_path, is_left):
    df = pd.read_csv(model_path)
    col = 'LKneeMoment_Y' if is_left else 'RKneeMoment_Y'
    return df[col].values

# ========== Dataset Class ==========

# Custom PyTorch Dataset class for loading KAM data
class KAMDataset(torch.utils.data.Dataset):
    def __init__(self, folder_path, selected_markers=None):
        self.data = [] # List to store dataset samples
        pairs = pair_files(folder_path) # Pair trajectory and model files

        for traj_path, model_path in pairs:
            is_left = is_left_file(traj_path)

            X = read_trajectory(traj_path, is_left, selected_markers)
            Y = read_kam(model_path, is_left)

            input_tensor = torch.tensor(X, dtype=torch.float32)
            target_tensor = torch.tensor(Y, dtype=torch.float32)
            filename = os.path.basename(model_path)

            self.data.append({
                'input': input_tensor,
                'target': target_tensor,
                'filename': filename
            })

        self.selected_markers = selected_markers # Store selected markers
        print(f"Loaded {len(self.data)} samples (using {X.shape[1]} markers)")

    def __len__(self):
        return len(self.data) # Return dataset size

    def __getitem__(self, idx):
        return self.data[idx] # Return dataset sample

# ========== collate_fn ==========

# Custom collate function for handling variable-length sequences in a batch
def collate_fn(batch):
    inputs = [item['input'] for item in batch]
    targets = [item['target'] for item in batch]
    lengths = [x.shape[0] for x in inputs]
    max_len = max(lengths)

    # Pad sequences to uniform length
    padded_inputs = pad_sequence(inputs, batch_first=True)  # (B, T, N, D)
    padded_targets = pad_sequence([y.unsqueeze(-1) for y in targets], batch_first=True).squeeze(-1)  # (B, T)

    # Create padding mask to indicate valid frames
    mask = torch.zeros((len(batch), max_len), dtype=torch.bool)
    for i, l in enumerate(lengths):
        mask[i, :l] = 1

    return padded_inputs, padded_targets, mask

# ========== Model Definitions ==========

# FrameEncoder: Extracts spatial features from each frame (marker-level data)
class FrameEncoder(nn.Module):
    def __init__(self, input_dim=9, out_dim=128):
        super().__init__()
        self.conv1 = nn.Conv2d(input_dim, 64, kernel_size=(1, 1))
        self.conv2 = nn.Conv2d(64, out_dim, kernel_size=(1, 1))
        self.bn1 = nn.BatchNorm2d(64)
        self.bn2 = nn.BatchNorm2d(out_dim)

    def forward(self, x):  # x: [B*T, C=9, N]
        B, C, N = x.shape
        x = x.unsqueeze(-1)  # → [B*T, C, N, 1]
        x = F.relu(self.bn1(self.conv1(x)))  # → [B*T, 64, N, 1]
        x = F.relu(self.bn2(self.conv2(x)))  # → [B*T, 128, N, 1]
        x = torch.max(x, dim=2)[0]  # Max-pool over N → [B*T, 128, 1, 1]
        x = x.view(B, -1)           # → [B*T, 128]
        return x

# Bidirectional LSTM for temporal modeling 
class BiLSTM(nn.Module):
    def __init__(self, input_size=128, hidden_size=96, num_layers=3, output_size=1):
        super().__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers=num_layers,
                            batch_first=True, bidirectional=True)
        self.fc = nn.Linear(hidden_size * 2, output_size)

    def forward(self, x, mask):  # x: [B, T, F], mask: [B, T]
        out, _ = self.lstm(x)             # → [B, T, 2*hidden]
        out = self.fc(out).squeeze(-1)    # → [B, T]
        return out * mask                 # apply mask to ignore padding

# Combined Spatial-Temporal Regressor
class SpatialTemporalLSTMRegressor(nn.Module):
    def __init__(self, input_dim=9, encoded_dim=128, lstm_hidden=96, lstm_layers=3):
        super().__init__()
        self.encoder = FrameEncoder(input_dim=input_dim, out_dim=encoded_dim)
        self.lstm = BiLSTM(input_size=encoded_dim,
                           hidden_size=lstm_hidden,
                           num_layers=lstm_layers,
                           output_size=1)

    def forward(self, x, mask):  # x: [B, T, N, D], mask: [B, T]
        B, T, N, D = x.shape
        x = x.permute(0, 1, 3, 2).reshape(B * T, D, N)  # → [B*T, D, N]
        feat = self.encoder(x)                         # → [B*T, 128]
        feat = feat.view(B, T, -1)                     # → [B, T, 128]
        out = self.lstm(feat, mask)                    # → [B, T]
        return out

# ========== Loss Function ==========

# Custom Mean Squared Error (MSE) loss that applies a mask to ignore padding
def masked_mse_loss(pred, target, mask):
    loss = F.mse_loss(pred, target, reduction='none')
    return (loss * mask).sum() / mask.sum()

# ========== Training Function ==========

# Function to train the model on the training set and evaluate on the validation set
def train_model(model, train_loader, val_loader, epochs=500, lr=1e-3, patience=50, save_path='best_model2.pth'):
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    best_loss = float('inf')
    patience_counter = 0
    train_losses, val_losses = [], []

    for epoch in range(epochs):
        model.train()
        total_train_loss = 0
        for x, y, m in train_loader:
            x = x.to(device)
            y = y.to(device)
            m = m.to(device)
            pred = model(x, m)
            loss = masked_mse_loss(pred, y, m)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_train_loss += loss.item()

        model.eval()
        total_val_loss = 0
        with torch.no_grad():
            for x, y, m in val_loader:
                x = x.to(device)
                y = y.to(device)
                m = m.to(device)
                pred = model(x, m)
                loss = masked_mse_loss(pred, y, m)
                total_val_loss += loss.item()

        # Compute average losses
        train_loss = total_train_loss / len(train_loader)
        val_loss = total_val_loss / len(val_loader)
        train_losses.append(train_loss)
        val_losses.append(val_loss)

        print(f"Epoch {epoch+1}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

        # Save model if validation loss improves
        if val_loss < best_loss:
            best_loss = val_loss
            torch.save(model.state_dict(), save_path)
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print("Early stopping triggered.")
                break

    # Plot loss curves
    plt.plot(train_losses, label='Train')
    plt.plot(val_losses, label='Val')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Loss Curve')
    plt.savefig('loss_curve.png')
    plt.close()

# ========== Evaluation Function ==========

# Function to evaluate the model on the test set and visualize predictions
def evaluate_model(model, test_loader, save_dir='results'):
    os.makedirs(save_dir, exist_ok=True)
    model.eval()
    total_mse, total_frames = 0, 0

    with torch.no_grad():
        for i, (x, y, m) in enumerate(test_loader):
            x = x.to(device)
            y = y.to(device)
            m = m.to(device)
            pred = model(x, m)
            for b in range(x.size(0)):
                T = int(m[b].sum().item())
                gt = y[b][:T].cpu().numpy()
                pr = pred[b][:T].cpu().numpy()
                mse = np.mean((gt - pr) ** 2)
                total_mse += mse * T
                total_frames += T

                # Plot ground truth vs. prediction for each sample
                plt.figure()
                plt.plot(gt, label='GT')
                plt.plot(pr, label='Pred')
                plt.xlabel('Frame')
                plt.ylabel('KAM')
                plt.title(f'Sample {i*test_loader.batch_size + b}, MSE: {mse:.4f}')
                plt.legend()
                plt.savefig(os.path.join(save_dir, f'sample_{i*test_loader.batch_size + b}.png'))
                plt.close()

    avg_mse = total_mse / total_frames # Compute average MSE across all frames
    print(f"Test MSE: {avg_mse:.6f}")

# ========== Reproducibility ==========

# Function to set a fixed random seed for reproducibility
def set_seed(seed=5703):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.use_deterministic_algorithms(True)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
# Function to compute saliency maps for identifying important markers
def compute_saliency_map_symmetric(model, dataloader, device='cuda', num_samples=2000):
    model = model.to(device)
    model.train()
    saliency_accum = None
    total_valid_frames = 0

    for x, y, m in dataloader:
        if total_valid_frames >= num_samples:
            break

        x = x.to(device).detach().requires_grad_(True)  # (B, T, N, D)
        m = m.to(device)  # (B, T)

        output = model(x, m)  # (B, T)
        loss = output.sum()
        loss.backward()

        grad = x.grad.detach()  # (B, T, N, D)

        # Expand the mask to match input dimensions and apply it to the gradients
        mask_expanded = m.unsqueeze(-1).unsqueeze(-1).float()
        grad = grad * mask_expanded  

        grad_abs = grad.abs()
        grad_sum = grad_abs.sum(dim=(1, 3))  # Sum gradients across time (T) and dimensions (D)

        if saliency_accum is None:
            saliency_accum = grad_sum.sum(dim=0)  
        else:
            saliency_accum += grad_sum.sum(dim=0)

        total_valid_frames += m.sum().item()  

    # Normalize saliency by total valid frames, not total samples
    saliency = saliency_accum.cpu().numpy() / total_valid_frames
    saliency = saliency / saliency.sum()  # normalize to sum 1

    # Merge saliency scores for symmetric markers (e.g., left/right)
    N = saliency.shape[0]

    left_markers = [p for p in FIXED_POINTS if p.startswith('L')]
    right_markers = [p for p in FIXED_POINTS if p.startswith('R')]

    # Determine whether the markers are left or right based on their count
    if N == len(left_markers):
        marker_names = left_markers
    elif N == len(right_markers):
        marker_names = right_markers
    else:
        raise ValueError("Unable to determine marker side.")

    # Group saliency scores by symmetric marker names (e.g., LANK and RANK → ANK)
    suffix_dict = {}
    for name, value in zip(marker_names, saliency):
        suffix = name[1:]  
        suffix_dict.setdefault(suffix, []).append(value)

    # Compute the average saliency score for each symmetric marker
    merged_saliency = {k: np.mean(v) for k, v in suffix_dict.items()}
    return merged_saliency

# %% [markdown]
# # 加载数据，初始化模型

# %%
set_seed(5703)

# Load dataset splits
train_set = KAMDataset(os.path.join('random_dataset', 'train'))
val_set = KAMDataset(os.path.join('random_dataset', 'val'))
test_set = KAMDataset(os.path.join('random_dataset', 'test'))

print(f"Training samples: {len(train_set)}, Validation samples: {len(val_set)}, Test samples: {len(test_set)}")

# Create DataLoaders
train_loader = DataLoader(train_set, batch_size=64, shuffle=True, collate_fn=collate_fn)
val_loader = DataLoader(val_set, batch_size=64, shuffle=False, collate_fn=collate_fn)
test_loader = DataLoader(test_set, batch_size=16, shuffle=False, collate_fn=collate_fn)

# Train baseline model using all markers
model = SpatialTemporalLSTMRegressor().to(device)
print(f"Model is running on: {next(model.parameters()).device}")
train_model(model, train_loader, val_loader, save_path='baseline_all_marker2.pth')
# Out:
# Loaded 2336 samples (using 14 markers)
# Loaded 292 samples (using 14 markers)
# Loaded 292 samples (using 14 markers)
# Training samples: 2336, Validation samples: 292, Test samples: 292
# Model is running on: cuda:0
# Epoch 1, Train Loss: 3.4697, Val Loss: 2.7769
# Epoch 2, Train Loss: 2.1747, Val Loss: 2.3459
# Epoch 3, Train Loss: 1.7870, Val Loss: 1.9601
# Epoch 4, Train Loss: 1.5528, Val Loss: 1.8089
# Epoch 5, Train Loss: 1.4573, Val Loss: 1.8809
# Epoch 6, Train Loss: 1.3610, Val Loss: 1.5131
# Epoch 7, Train Loss: 1.3190, Val Loss: 1.4448
# Epoch 8, Train Loss: 1.1197, Val Loss: 1.4038
# Epoch 9, Train Loss: 1.0298, Val Loss: 1.4367
# Epoch 10, Train Loss: 1.0117, Val Loss: 1.1328
# Epoch 11, Train Loss: 0.9012, Val Loss: 1.1694
# Epoch 12, Train Loss: 0.8603, Val Loss: 0.9830
# Epoch 13, Train Loss: 0.9274, Val Loss: 1.2792
# Epoch 14, Train Loss: 0.9245, Val Loss: 0.9985
# Epoch 15, Train Loss: 0.7462, Val Loss: 0.8460
# Epoch 16, Train Loss: 0.6766, Val Loss: 1.0323
# Epoch 17, Train Loss: 0.6963, Val Loss: 1.0127
# Epoch 18, Train Loss: 0.7072, Val Loss: 0.8627
# Epoch 19, Train Loss: 0.6290, Val Loss: 0.7857
# Epoch 20, Train Loss: 0.5765, Val Loss: 0.9355
# Epoch 21, Train Loss: 0.6265, Val Loss: 0.6974
# Epoch 22, Train Loss: 0.5483, Val Loss: 0.8252
# Epoch 23, Train Loss: 0.5580, Val Loss: 0.6948
# Epoch 24, Train Loss: 0.5423, Val Loss: 0.6520
# Epoch 25, Train Loss: 0.4658, Val Loss: 0.5982
# Epoch 26, Train Loss: 0.4487, Val Loss: 0.7398
# Epoch 27, Train Loss: 0.4592, Val Loss: 0.7304
# Epoch 28, Train Loss: 0.4439, Val Loss: 0.6404
# Epoch 29, Train Loss: 0.4295, Val Loss: 0.5467
# Epoch 30, Train Loss: 0.4605, Val Loss: 0.5381
# Epoch 31, Train Loss: 0.3691, Val Loss: 0.5341
# Epoch 32, Train Loss: 0.3939, Val Loss: 0.5440
# Epoch 33, Train Loss: 0.3426, Val Loss: 0.5142
# Epoch 34, Train Loss: 0.3365, Val Loss: 0.5968
# Epoch 35, Train Loss: 0.3619, Val Loss: 0.5700
# Epoch 36, Train Loss: 0.3088, Val Loss: 0.5113
# Epoch 37, Train Loss: 0.2895, Val Loss: 0.4792
# Epoch 38, Train Loss: 0.2672, Val Loss: 0.4752
# Epoch 39, Train Loss: 0.2719, Val Loss: 0.4833
# Epoch 40, Train Loss: 0.2655, Val Loss: 0.5053
# Epoch 41, Train Loss: 0.2629, Val Loss: 0.4737
# Epoch 42, Train Loss: 0.2937, Val Loss: 0.6331
# Epoch 43, Train Loss: 0.2968, Val Loss: 0.4901
# Epoch 44, Train Loss: 0.2482, Val Loss: 0.4911
# Epoch 45, Train Loss: 0.2330, Val Loss: 0.4889
# Epoch 46, Train Loss: 0.2285, Val Loss: 0.4566
# Epoch 47, Train Loss: 0.2214, Val Loss: 0.4829
# Epoch 48, Train Loss: 0.2028, Val Loss: 0.4739
# Epoch 49, Train Loss: 0.1899, Val Loss: 0.4572
# Epoch 50, Train Loss: 0.1839, Val Loss: 0.4418
# Epoch 51, Train Loss: 0.1820, Val Loss: 0.4680
# Epoch 52, Train Loss: 0.1791, Val Loss: 0.4483
# Epoch 53, Train Loss: 0.1547, Val Loss: 0.4449
# Epoch 54, Train Loss: 0.1663, Val Loss: 0.4543
# Epoch 55, Train Loss: 0.1643, Val Loss: 0.4354
# Epoch 56, Train Loss: 0.1566, Val Loss: 0.4391
# Epoch 57, Train Loss: 0.1392, Val Loss: 0.4286
# Epoch 58, Train Loss: 0.1373, Val Loss: 0.4046
# Epoch 59, Train Loss: 0.1384, Val Loss: 0.4484
# Epoch 60, Train Loss: 0.1310, Val Loss: 0.4151
# Epoch 61, Train Loss: 0.1270, Val Loss: 0.4371
# Epoch 62, Train Loss: 0.1251, Val Loss: 0.4010
# Epoch 63, Train Loss: 0.1307, Val Loss: 0.4539
# Epoch 64, Train Loss: 0.1233, Val Loss: 0.4064
# Epoch 65, Train Loss: 0.1057, Val Loss: 0.4125
# Epoch 66, Train Loss: 0.0948, Val Loss: 0.4237
# Epoch 67, Train Loss: 0.1037, Val Loss: 0.4306
# Epoch 68, Train Loss: 0.1046, Val Loss: 0.4292
# Epoch 69, Train Loss: 0.1062, Val Loss: 0.4323
# Epoch 70, Train Loss: 0.1215, Val Loss: 0.4423
# Epoch 71, Train Loss: 0.1455, Val Loss: 0.4670
# Epoch 72, Train Loss: 0.1205, Val Loss: 0.4566
# Epoch 73, Train Loss: 0.1046, Val Loss: 0.4180
# Epoch 74, Train Loss: 0.0981, Val Loss: 0.4371
# Epoch 75, Train Loss: 0.1017, Val Loss: 0.4121
# Epoch 76, Train Loss: 0.1003, Val Loss: 0.4332
# Epoch 77, Train Loss: 0.0917, Val Loss: 0.4241
# Epoch 78, Train Loss: 0.0824, Val Loss: 0.4067
# Epoch 79, Train Loss: 0.0857, Val Loss: 0.5053
# Epoch 80, Train Loss: 0.0882, Val Loss: 0.4462
# Epoch 81, Train Loss: 0.0898, Val Loss: 0.3948
# Epoch 82, Train Loss: 0.0783, Val Loss: 0.3848
# Epoch 83, Train Loss: 0.0685, Val Loss: 0.3932
# Epoch 84, Train Loss: 0.0657, Val Loss: 0.3785
# Epoch 85, Train Loss: 0.0645, Val Loss: 0.3992
# Epoch 86, Train Loss: 0.0621, Val Loss: 0.3998
# Epoch 87, Train Loss: 0.0620, Val Loss: 0.3935
# Epoch 88, Train Loss: 0.0717, Val Loss: 0.4116
# Epoch 89, Train Loss: 0.0712, Val Loss: 0.4039
# Epoch 90, Train Loss: 0.0783, Val Loss: 0.3915
# Epoch 91, Train Loss: 0.0740, Val Loss: 0.3950
# Epoch 92, Train Loss: 0.0692, Val Loss: 0.4070
# Epoch 93, Train Loss: 0.0590, Val Loss: 0.3943
# Epoch 94, Train Loss: 0.0636, Val Loss: 0.3895
# Epoch 95, Train Loss: 0.0702, Val Loss: 0.4047
# Epoch 96, Train Loss: 0.0564, Val Loss: 0.3949
# Epoch 97, Train Loss: 0.0576, Val Loss: 0.4242
# Epoch 98, Train Loss: 0.0832, Val Loss: 0.3998
# Epoch 99, Train Loss: 0.0632, Val Loss: 0.4230
# Epoch 100, Train Loss: 0.0556, Val Loss: 0.3782
# Epoch 101, Train Loss: 0.0527, Val Loss: 0.3917
# Epoch 102, Train Loss: 0.0576, Val Loss: 0.4015
# Epoch 103, Train Loss: 0.0520, Val Loss: 0.4016
# Epoch 104, Train Loss: 0.0478, Val Loss: 0.3960
# Epoch 105, Train Loss: 0.0442, Val Loss: 0.3922
# Epoch 106, Train Loss: 0.0505, Val Loss: 0.4119
# Epoch 107, Train Loss: 0.0472, Val Loss: 0.3830
# Epoch 108, Train Loss: 0.0439, Val Loss: 0.4068
# Epoch 109, Train Loss: 0.0416, Val Loss: 0.3901
# Epoch 110, Train Loss: 0.0406, Val Loss: 0.3805
# Epoch 111, Train Loss: 0.0402, Val Loss: 0.4029
# Epoch 112, Train Loss: 0.0448, Val Loss: 0.3912
# Epoch 113, Train Loss: 0.0447, Val Loss: 0.3936
# Epoch 114, Train Loss: 0.0555, Val Loss: 0.3975
# Epoch 115, Train Loss: 0.0515, Val Loss: 0.4024
# Epoch 116, Train Loss: 0.0395, Val Loss: 0.3960
# Epoch 117, Train Loss: 0.0376, Val Loss: 0.3973
# Epoch 118, Train Loss: 0.0346, Val Loss: 0.3834
# Epoch 119, Train Loss: 0.0350, Val Loss: 0.3955
# Epoch 120, Train Loss: 0.0409, Val Loss: 0.4075
# Epoch 121, Train Loss: 0.0387, Val Loss: 0.4027
# Epoch 122, Train Loss: 0.0372, Val Loss: 0.3818
# Epoch 123, Train Loss: 0.0353, Val Loss: 0.3657
# Epoch 124, Train Loss: 0.0361, Val Loss: 0.4090
# Epoch 125, Train Loss: 0.0501, Val Loss: 0.4110
# Epoch 126, Train Loss: 0.2598, Val Loss: 1.0725
# Epoch 127, Train Loss: 0.9299, Val Loss: 1.0091
# Epoch 128, Train Loss: 0.6044, Val Loss: 0.7079
# Epoch 129, Train Loss: 0.3753, Val Loss: 0.6158
# Epoch 130, Train Loss: 0.3142, Val Loss: 0.5075
# Epoch 131, Train Loss: 0.2009, Val Loss: 0.4805
# Epoch 132, Train Loss: 0.2603, Val Loss: 0.6412
# Epoch 133, Train Loss: 0.2599, Val Loss: 0.4587
# Epoch 134, Train Loss: 0.1657, Val Loss: 0.4728
# Epoch 135, Train Loss: 0.1189, Val Loss: 0.4309
# Epoch 136, Train Loss: 0.0931, Val Loss: 0.4244
# Epoch 137, Train Loss: 0.0772, Val Loss: 0.4174
# Epoch 138, Train Loss: 0.0700, Val Loss: 0.4215
# Epoch 139, Train Loss: 0.0628, Val Loss: 0.4028
# Epoch 140, Train Loss: 0.0592, Val Loss: 0.3895
# Epoch 141, Train Loss: 0.0555, Val Loss: 0.3894
# Epoch 142, Train Loss: 0.0491, Val Loss: 0.4014
# Epoch 143, Train Loss: 0.0448, Val Loss: 0.3893
# Epoch 144, Train Loss: 0.0426, Val Loss: 0.4002
# Epoch 145, Train Loss: 0.0378, Val Loss: 0.4052
# Epoch 146, Train Loss: 0.0395, Val Loss: 0.3827
# Epoch 147, Train Loss: 0.0375, Val Loss: 0.4057
# Epoch 148, Train Loss: 0.0359, Val Loss: 0.3996
# Epoch 149, Train Loss: 0.0351, Val Loss: 0.3979
# Epoch 150, Train Loss: 0.0338, Val Loss: 0.3958
# Epoch 151, Train Loss: 0.0333, Val Loss: 0.3955
# Epoch 152, Train Loss: 0.0330, Val Loss: 0.3966
# Epoch 153, Train Loss: 0.0335, Val Loss: 0.4023
# Epoch 154, Train Loss: 0.0300, Val Loss: 0.3937
# Epoch 155, Train Loss: 0.0301, Val Loss: 0.3965
# Epoch 156, Train Loss: 0.0319, Val Loss: 0.3946
# Epoch 157, Train Loss: 0.0319, Val Loss: 0.3982
# Epoch 158, Train Loss: 0.0301, Val Loss: 0.3978
# Epoch 159, Train Loss: 0.0285, Val Loss: 0.3839
# Epoch 160, Train Loss: 0.0282, Val Loss: 0.3878
# Epoch 161, Train Loss: 0.0266, Val Loss: 0.3998
# Epoch 162, Train Loss: 0.0276, Val Loss: 0.3996
# Epoch 163, Train Loss: 0.0267, Val Loss: 0.3967
# Epoch 164, Train Loss: 0.0263, Val Loss: 0.3948
# Epoch 165, Train Loss: 0.0244, Val Loss: 0.3954
# Epoch 166, Train Loss: 0.0239, Val Loss: 0.3923
# Epoch 167, Train Loss: 0.0222, Val Loss: 0.3978
# Epoch 168, Train Loss: 0.0242, Val Loss: 0.4034
# Epoch 169, Train Loss: 0.0225, Val Loss: 0.3972
# Epoch 170, Train Loss: 0.0228, Val Loss: 0.4061
# Epoch 171, Train Loss: 0.0255, Val Loss: 0.4000
# Epoch 172, Train Loss: 0.0241, Val Loss: 0.4017
# Epoch 173, Train Loss: 0.0224, Val Loss: 0.3932
# Early stopping triggered.

# %% [markdown]
# # 计算marker重要性

# %%
# ========== Saliency Analysis and Visualization ==========

set_seed(5703)

import matplotlib.pyplot as plt

plt.rcParams.update({
    'figure.dpi': 100,
    'savefig.dpi': 100,
    'font.size': 12,
    'axes.titlesize': 14,
    'axes.labelsize': 12,
    'xtick.labelsize': 10,
    'ytick.labelsize': 10,
    'legend.fontsize': 10,
    'figure.figsize': (12, 4),
})

# Load trained model and compute saliency map
model.load_state_dict(torch.load('baseline_all_marker2.pth'))
model.eval()
merged_saliency = compute_saliency_map_symmetric(model, val_loader, device=device)

# Visualize saliency map
sorted_items = sorted(merged_saliency.items(), key=lambda x: -x[1])
labels, values = zip(*sorted_items)

# Plot saliency scores for markers
plt.figure()
plt.bar(labels, values, color='tab:blue')  
plt.xticks(rotation=90)
plt.ylabel("Normalized Saliency")
plt.title("CNN+LSTM Symmetric Marker Saliency")
plt.tight_layout()
plt.savefig("merged_saliency.png")
plt.show()


# Print the top 10 most influential symmetric markers
print("Top influential symmetric markers:")
for name, score in sorted_items[:10]:
    print(f"{name}: {score:.4f}")
# Out:
# Top influential symmetric markers:
# PSI: 0.1290
# ASI: 0.1182
# HEE: 0.1101
# THAP: 0.0995
# FMH: 0.0901
# KNE: 0.0733
# VMH: 0.0678
# THAD: 0.0630
# TIAP: 0.0582
# THI: 0.0567

# %% [markdown]
# # marker筛选

# %%
# ========== Evaluate Marker Combinations for Model Performance ==========

# Function to evaluate model performance with different subsets of markers based on saliency scores
def evaluate_marker_combinations(
    saliency_dict,
    top_k_list,
    root_dir='random_dataset',
    epochs=500,
    patience=50,
    all_marker_result=None,
    final_model_path='best_marker_combination2.pth'
):
    """
    Evaluate model performance with different top-k marker subsets selected by saliency.

    Args:
        saliency_dict (dict): Symmetric saliency scores, e.g., {'ANK': 0.12, ...}
        top_k_list (list): List of k values for top-k marker selection, e.g., [4, 6, 11]
        root_dir (str): Path to dataset root folder containing 'train' and 'val'
        epochs (int): Maximum number of training epochs
        patience (int): Early stopping patience
        all_marker_result (float or None): Optional val loss of all-marker model for comparison
        final_model_path (str): Path to save the best-performing model

    Returns:
        results (list): List of tuples (Top-k name, selected suffixes, val loss)
    """
    results = []
    sorted_markers = sorted(saliency_dict.items(), key=lambda x: -x[1])
    best_model_file = None

    # Iterate through the specified top-k subsets
    for k in top_k_list:
        selected_suffixes = [name for name, _ in sorted_markers[:k]]
        print(f"\n Training with Top-{k} markers: {selected_suffixes}")

        # Prepare datasets and loaders
        train_set = KAMDataset(os.path.join(root_dir, 'train'), selected_suffixes)
        val_set = KAMDataset(os.path.join(root_dir, 'val'), selected_suffixes)

        train_loader = DataLoader(train_set, batch_size=64, shuffle=True, collate_fn=collate_fn)
        val_loader = DataLoader(val_set, batch_size=64, shuffle=False, collate_fn=collate_fn)

        # Train model
        model = SpatialTemporalLSTMRegressor()
        model_save_path = f"CNN_LSTM_top_{k}.pth"
        train_model(model, train_loader, val_loader, epochs=epochs, patience=patience, save_path=model_save_path)
        model.load_state_dict(torch.load(model_save_path))

        # Evaluate on validation set
        model.eval()
        total_val_loss = 0
        total_count = 0
        with torch.no_grad():
            for x, y, m in val_loader:
                x = x.to(device)
                y = y.to(device)
                m = m.to(device)
                pred = model(x, m)
                loss = masked_mse_loss(pred, y, m)
                total_val_loss += loss.item() * x.size(0)
                total_count += x.size(0)

        avg_val_loss = total_val_loss / total_count
        results.append((f"Top-{k}", selected_suffixes, avg_val_loss))
        print(f"Top-{k} markers Val Loss: {avg_val_loss:.6f}")

        # Track the best model file based on validation loss
        if best_model_file is None or avg_val_loss < min([r[2] for r in results[:-1]]):
            best_model_file = model_save_path

    # Add all-marker baseline result (if provided)
    if all_marker_result is not None:
        results.append(("All", "All markers", all_marker_result))
        print(f"\n Included all markers baseline Val Loss: {all_marker_result:.6f}")

    # Report the best-performing marker combination
    best = min(results, key=lambda x: x[2]) # Find the combination with the lowest validation loss
    print("\n Best marker combination:")
    print(f"{best[0]} markers: {best[1]}")
    print(f"Val Loss: {best[2]:.6f}")

    # Save best model
    if best_model_file is not None:
        import shutil
        shutil.copyfile(best_model_file, final_model_path)
        print(f" Best model saved to: {final_model_path}")

    return results, best[1]

# %%
# ========== Evaluate Top Marker Combinations ==========

set_seed(5703)

# Evaluate model performance with different top-k marker subsets
results, best_markers = evaluate_marker_combinations(
    merged_saliency,
    top_k_list=[4, 5, 6, 7, 8, 10, 12, 14],
    all_marker_result=None,
    final_model_path='best_marker_combination2.pth'
)

# ========== Test Best Model on Test Set ==========

# Load the best-performing model
model = SpatialTemporalLSTMRegressor().to(device)
model.load_state_dict(torch.load('best_marker_combination2.pth', map_location=device))
model.eval()  

test_set = KAMDataset('random_dataset/test', selected_markers=best_markers)
test_loader = DataLoader(test_set, batch_size=64, shuffle=False, collate_fn=collate_fn)

# Evaluate the model on the test set
evaluate_model(model, test_loader)
# Out:
#  Training with Top-4 markers: ['PSI', 'ASI', 'HEE', 'THAP']
# Loaded 2336 samples (using 4 markers)
# Loaded 292 samples (using 4 markers)
# Epoch 1, Train Loss: 3.4056, Val Loss: 2.6429
# Epoch 2, Train Loss: 2.0669, Val Loss: 2.4555
# Epoch 3, Train Loss: 1.8364, Val Loss: 2.5178
# Epoch 4, Train Loss: 1.6702, Val Loss: 1.8856
# Epoch 5, Train Loss: 1.4646, Val Loss: 1.6938
# Epoch 6, Train Loss: 1.3850, Val Loss: 1.5911
# Epoch 7, Train Loss: 1.3216, Val Loss: 1.5866
# Epoch 8, Train Loss: 1.2819, Val Loss: 1.3633
# Epoch 9, Train Loss: 1.0955, Val Loss: 1.3281
# Epoch 10, Train Loss: 0.9715, Val Loss: 1.1480
# Epoch 11, Train Loss: 0.9390, Val Loss: 1.2281
# Epoch 12, Train Loss: 0.8999, Val Loss: 0.9524
# Epoch 13, Train Loss: 0.8895, Val Loss: 1.2709
# Epoch 14, Train Loss: 0.8873, Val Loss: 0.9309
# Epoch 15, Train Loss: 0.7571, Val Loss: 0.9336
# Epoch 16, Train Loss: 0.6810, Val Loss: 0.9775
# Epoch 17, Train Loss: 0.6298, Val Loss: 0.8350
# Epoch 18, Train Loss: 0.6553, Val Loss: 0.8305
# Epoch 19, Train Loss: 0.6724, Val Loss: 0.8855
# Epoch 20, Train Loss: 0.5838, Val Loss: 0.8226
# Epoch 21, Train Loss: 0.5481, Val Loss: 0.7383
# Epoch 22, Train Loss: 0.5024, Val Loss: 0.7832
# Epoch 23, Train Loss: 0.5360, Val Loss: 0.7209
# Epoch 24, Train Loss: 0.4593, Val Loss: 0.7747
# Epoch 25, Train Loss: 0.4371, Val Loss: 0.6165
# Epoch 26, Train Loss: 0.3988, Val Loss: 0.6072
# Epoch 27, Train Loss: 0.3871, Val Loss: 0.6691
# Epoch 28, Train Loss: 0.3668, Val Loss: 0.6112
# Epoch 29, Train Loss: 0.4016, Val Loss: 0.8172
# Epoch 30, Train Loss: 0.4074, Val Loss: 0.8044
# Epoch 31, Train Loss: 0.3850, Val Loss: 0.5985
# Epoch 32, Train Loss: 0.3543, Val Loss: 0.6123
# Epoch 33, Train Loss: 0.3291, Val Loss: 0.6222
# Epoch 34, Train Loss: 0.3047, Val Loss: 0.5572
# Epoch 35, Train Loss: 0.2845, Val Loss: 0.5957
# Epoch 36, Train Loss: 0.3330, Val Loss: 0.6443
# Epoch 37, Train Loss: 0.2841, Val Loss: 0.5892
# Epoch 38, Train Loss: 0.2522, Val Loss: 0.5249
# Epoch 39, Train Loss: 0.2440, Val Loss: 0.4925
# Epoch 40, Train Loss: 0.2261, Val Loss: 0.5233
# Epoch 41, Train Loss: 0.2130, Val Loss: 0.5298
# Epoch 42, Train Loss: 0.2081, Val Loss: 0.5897
# Epoch 43, Train Loss: 0.2412, Val Loss: 0.5899
# Epoch 44, Train Loss: 0.2187, Val Loss: 0.5101
# Epoch 45, Train Loss: 0.1804, Val Loss: 0.4915
# Epoch 46, Train Loss: 0.1779, Val Loss: 0.5174
# Epoch 47, Train Loss: 0.1694, Val Loss: 0.5142
# Epoch 48, Train Loss: 0.1767, Val Loss: 0.5427
# Epoch 49, Train Loss: 0.1962, Val Loss: 0.5121
# Epoch 50, Train Loss: 0.1707, Val Loss: 0.4802
# Epoch 51, Train Loss: 0.1454, Val Loss: 0.4891
# Epoch 52, Train Loss: 0.1303, Val Loss: 0.4665
# Epoch 53, Train Loss: 0.1256, Val Loss: 0.4589
# Epoch 54, Train Loss: 0.1182, Val Loss: 0.4982
# Epoch 55, Train Loss: 0.1250, Val Loss: 0.4410
# Epoch 56, Train Loss: 0.1349, Val Loss: 0.4878
# Epoch 57, Train Loss: 0.1264, Val Loss: 0.4777
# Epoch 58, Train Loss: 0.1134, Val Loss: 0.4676
# Epoch 59, Train Loss: 0.1020, Val Loss: 0.4725
# Epoch 60, Train Loss: 0.0971, Val Loss: 0.4324
# Epoch 61, Train Loss: 0.0977, Val Loss: 0.4711
# Epoch 62, Train Loss: 0.0993, Val Loss: 0.4990
# Epoch 63, Train Loss: 0.1227, Val Loss: 0.4680
# Epoch 64, Train Loss: 0.1115, Val Loss: 0.4352
# Epoch 65, Train Loss: 0.0989, Val Loss: 0.4682
# Epoch 66, Train Loss: 0.0911, Val Loss: 0.4550
# Epoch 67, Train Loss: 0.0849, Val Loss: 0.4496
# Epoch 68, Train Loss: 0.0881, Val Loss: 0.4396
# Epoch 69, Train Loss: 0.0948, Val Loss: 0.4917
# Epoch 70, Train Loss: 0.1693, Val Loss: 0.4923
# Epoch 71, Train Loss: 0.1805, Val Loss: 0.4781
# Epoch 72, Train Loss: 0.1174, Val Loss: 0.4378
# Epoch 73, Train Loss: 0.0905, Val Loss: 0.4313
# Epoch 74, Train Loss: 0.0808, Val Loss: 0.4432
# Epoch 75, Train Loss: 0.0724, Val Loss: 0.4341
# Epoch 76, Train Loss: 0.0668, Val Loss: 0.4441
# Epoch 77, Train Loss: 0.0645, Val Loss: 0.4323
# Epoch 78, Train Loss: 0.0605, Val Loss: 0.4586
# Epoch 79, Train Loss: 0.0623, Val Loss: 0.4167
# Epoch 80, Train Loss: 0.0684, Val Loss: 0.4317
# Epoch 81, Train Loss: 0.0636, Val Loss: 0.4322
# Epoch 82, Train Loss: 0.0584, Val Loss: 0.4114
# Epoch 83, Train Loss: 0.0523, Val Loss: 0.4206
# Epoch 84, Train Loss: 0.0531, Val Loss: 0.4272
# Epoch 85, Train Loss: 0.0530, Val Loss: 0.4539
# Epoch 86, Train Loss: 0.0540, Val Loss: 0.4153
# Epoch 87, Train Loss: 0.0503, Val Loss: 0.4155
# Epoch 88, Train Loss: 0.0492, Val Loss: 0.4281
# Epoch 89, Train Loss: 0.0531, Val Loss: 0.4205
# Epoch 90, Train Loss: 0.0493, Val Loss: 0.4115
# Epoch 91, Train Loss: 0.0568, Val Loss: 0.4407
# Epoch 92, Train Loss: 0.0959, Val Loss: 0.4893
# Epoch 93, Train Loss: 0.0905, Val Loss: 0.4466
# Epoch 94, Train Loss: 0.0805, Val Loss: 0.4414
# Epoch 95, Train Loss: 0.0602, Val Loss: 0.4448
# Epoch 96, Train Loss: 0.0539, Val Loss: 0.4302
# Epoch 97, Train Loss: 0.0503, Val Loss: 0.4080
# Epoch 98, Train Loss: 0.0458, Val Loss: 0.4075
# Epoch 99, Train Loss: 0.0400, Val Loss: 0.4042
# Epoch 100, Train Loss: 0.0435, Val Loss: 0.4152
# Epoch 101, Train Loss: 0.0379, Val Loss: 0.3959
# Epoch 102, Train Loss: 0.0393, Val Loss: 0.4251
# Epoch 103, Train Loss: 0.0372, Val Loss: 0.4066
# Epoch 104, Train Loss: 0.0366, Val Loss: 0.4066
# Epoch 105, Train Loss: 0.0371, Val Loss: 0.4258
# Epoch 106, Train Loss: 0.0374, Val Loss: 0.4074
# Epoch 107, Train Loss: 0.0342, Val Loss: 0.4180
# Epoch 108, Train Loss: 0.0426, Val Loss: 0.4495
# Epoch 109, Train Loss: 0.0382, Val Loss: 0.4412
# Epoch 110, Train Loss: 0.0355, Val Loss: 0.4129
# Epoch 111, Train Loss: 0.0327, Val Loss: 0.4215
# Epoch 112, Train Loss: 0.0343, Val Loss: 0.3989
# Epoch 113, Train Loss: 0.0328, Val Loss: 0.4081
# Epoch 114, Train Loss: 0.0376, Val Loss: 0.4172
# Epoch 115, Train Loss: 0.0338, Val Loss: 0.3954
# Epoch 116, Train Loss: 0.0278, Val Loss: 0.4088
# Epoch 117, Train Loss: 0.0260, Val Loss: 0.4194
# Epoch 118, Train Loss: 0.0259, Val Loss: 0.4086
# Epoch 119, Train Loss: 0.0304, Val Loss: 0.4025
# Epoch 120, Train Loss: 0.0301, Val Loss: 0.4319
# Epoch 121, Train Loss: 0.0318, Val Loss: 0.4223
# Epoch 122, Train Loss: 0.0368, Val Loss: 0.4254
# Epoch 123, Train Loss: 0.0366, Val Loss: 0.4083
# Epoch 124, Train Loss: 0.0380, Val Loss: 0.4197
# Epoch 125, Train Loss: 0.0492, Val Loss: 0.4329
# Epoch 126, Train Loss: 0.0584, Val Loss: 0.4616
# Epoch 127, Train Loss: 0.0674, Val Loss: 0.4932
# Epoch 128, Train Loss: 0.2483, Val Loss: 0.9455
# Epoch 129, Train Loss: 0.9462, Val Loss: 0.8876
# Epoch 130, Train Loss: 0.8539, Val Loss: 0.8104
# Epoch 131, Train Loss: 0.4804, Val Loss: 0.6031
# Epoch 132, Train Loss: 0.3299, Val Loss: 0.5851
# Epoch 133, Train Loss: 0.2277, Val Loss: 0.5007
# Epoch 134, Train Loss: 0.1603, Val Loss: 0.4769
# Epoch 135, Train Loss: 0.1199, Val Loss: 0.4389
# Epoch 136, Train Loss: 0.0905, Val Loss: 0.4326
# Epoch 137, Train Loss: 0.0729, Val Loss: 0.4480
# Epoch 138, Train Loss: 0.0648, Val Loss: 0.4325
# Epoch 139, Train Loss: 0.0600, Val Loss: 0.4244
# Epoch 140, Train Loss: 0.0518, Val Loss: 0.4240
# Epoch 141, Train Loss: 0.0497, Val Loss: 0.4336
# Epoch 142, Train Loss: 0.0457, Val Loss: 0.4119
# Epoch 143, Train Loss: 0.0387, Val Loss: 0.4114
# Epoch 144, Train Loss: 0.0397, Val Loss: 0.4133
# Epoch 145, Train Loss: 0.0358, Val Loss: 0.4118
# Epoch 146, Train Loss: 0.0352, Val Loss: 0.4086
# Epoch 147, Train Loss: 0.0321, Val Loss: 0.4084
# Epoch 148, Train Loss: 0.0301, Val Loss: 0.4136
# Epoch 149, Train Loss: 0.0310, Val Loss: 0.4065
# Epoch 150, Train Loss: 0.0288, Val Loss: 0.4095
# Epoch 151, Train Loss: 0.0279, Val Loss: 0.4174
# Epoch 152, Train Loss: 0.0295, Val Loss: 0.4017
# Epoch 153, Train Loss: 0.0279, Val Loss: 0.4054
# Epoch 154, Train Loss: 0.0250, Val Loss: 0.4047
# Epoch 155, Train Loss: 0.0251, Val Loss: 0.4110
# Epoch 156, Train Loss: 0.0251, Val Loss: 0.4112
# Epoch 157, Train Loss: 0.0257, Val Loss: 0.4021
# Epoch 158, Train Loss: 0.0243, Val Loss: 0.3944
# Epoch 159, Train Loss: 0.0234, Val Loss: 0.3957
# Epoch 160, Train Loss: 0.0224, Val Loss: 0.3995
# Epoch 161, Train Loss: 0.0220, Val Loss: 0.4040
# Epoch 162, Train Loss: 0.0202, Val Loss: 0.3998
# Epoch 163, Train Loss: 0.0214, Val Loss: 0.4000
# Epoch 164, Train Loss: 0.0195, Val Loss: 0.4039
# Epoch 165, Train Loss: 0.0198, Val Loss: 0.4062
# Epoch 166, Train Loss: 0.0193, Val Loss: 0.3997
# Epoch 167, Train Loss: 0.0195, Val Loss: 0.4037
# Epoch 168, Train Loss: 0.0205, Val Loss: 0.4002
# Epoch 169, Train Loss: 0.0192, Val Loss: 0.3943
# Epoch 170, Train Loss: 0.0202, Val Loss: 0.3984
# Epoch 171, Train Loss: 0.0201, Val Loss: 0.4039
# Epoch 172, Train Loss: 0.0223, Val Loss: 0.3959
# Epoch 173, Train Loss: 0.0207, Val Loss: 0.3943
# Epoch 174, Train Loss: 0.0189, Val Loss: 0.3974
# Epoch 175, Train Loss: 0.0184, Val Loss: 0.3932
# Epoch 176, Train Loss: 0.0172, Val Loss: 0.3983
# Epoch 177, Train Loss: 0.0187, Val Loss: 0.3974
# Epoch 178, Train Loss: 0.0190, Val Loss: 0.4032
# Epoch 179, Train Loss: 0.0202, Val Loss: 0.3996
# Epoch 180, Train Loss: 0.0177, Val Loss: 0.3953
# Epoch 181, Train Loss: 0.0182, Val Loss: 0.3962
# Epoch 182, Train Loss: 0.0182, Val Loss: 0.3947
# Epoch 183, Train Loss: 0.0195, Val Loss: 0.3947
# Epoch 184, Train Loss: 0.0204, Val Loss: 0.3975
# Epoch 185, Train Loss: 0.0219, Val Loss: 0.3882
# Epoch 186, Train Loss: 0.0194, Val Loss: 0.4010
# Epoch 187, Train Loss: 0.0174, Val Loss: 0.3900
# Epoch 188, Train Loss: 0.0198, Val Loss: 0.3975
# Epoch 189, Train Loss: 0.0187, Val Loss: 0.3921
# Epoch 190, Train Loss: 0.0193, Val Loss: 0.3887
# Epoch 191, Train Loss: 0.0169, Val Loss: 0.3833
# Epoch 192, Train Loss: 0.0187, Val Loss: 0.3987
# Epoch 193, Train Loss: 0.0379, Val Loss: 0.4139
# Epoch 194, Train Loss: 0.0565, Val Loss: 0.4732
# Epoch 195, Train Loss: 0.0630, Val Loss: 0.4511
# Epoch 196, Train Loss: 0.0546, Val Loss: 0.4162
# Epoch 197, Train Loss: 0.0722, Val Loss: 0.4295
# Epoch 198, Train Loss: 0.0936, Val Loss: 0.4762
# Epoch 199, Train Loss: 0.0771, Val Loss: 0.4873
# Epoch 200, Train Loss: 0.2602, Val Loss: 0.7687
# Epoch 201, Train Loss: 0.4386, Val Loss: 0.6676
# Epoch 202, Train Loss: 0.4221, Val Loss: 0.6719
# Epoch 203, Train Loss: 0.3031, Val Loss: 0.5421
# Epoch 204, Train Loss: 0.1981, Val Loss: 0.4668
# Epoch 205, Train Loss: 0.1067, Val Loss: 0.4210
# Epoch 206, Train Loss: 0.0689, Val Loss: 0.4167
# Epoch 207, Train Loss: 0.0520, Val Loss: 0.4059
# Epoch 208, Train Loss: 0.0423, Val Loss: 0.4029
# Epoch 209, Train Loss: 0.0361, Val Loss: 0.4001
# Epoch 210, Train Loss: 0.0339, Val Loss: 0.3980
# Epoch 211, Train Loss: 0.0438, Val Loss: 0.4065
# Epoch 212, Train Loss: 0.0307, Val Loss: 0.3974
# Epoch 213, Train Loss: 0.0276, Val Loss: 0.3896
# Epoch 214, Train Loss: 0.0250, Val Loss: 0.3921
# Epoch 215, Train Loss: 0.0233, Val Loss: 0.3984
# Epoch 216, Train Loss: 0.0218, Val Loss: 0.3943
# Epoch 217, Train Loss: 0.0229, Val Loss: 0.3940
# Epoch 218, Train Loss: 0.0209, Val Loss: 0.3956
# Epoch 219, Train Loss: 0.0202, Val Loss: 0.4059
# Epoch 220, Train Loss: 0.0184, Val Loss: 0.3980
# Epoch 221, Train Loss: 0.0176, Val Loss: 0.3921
# Epoch 222, Train Loss: 0.0177, Val Loss: 0.3962
# Epoch 223, Train Loss: 0.0169, Val Loss: 0.3892
# Epoch 224, Train Loss: 0.0167, Val Loss: 0.3843
# Epoch 225, Train Loss: 0.0164, Val Loss: 0.3951
# Epoch 226, Train Loss: 0.0154, Val Loss: 0.3871
# Epoch 227, Train Loss: 0.0155, Val Loss: 0.3911
# Epoch 228, Train Loss: 0.0153, Val Loss: 0.3974
# Epoch 229, Train Loss: 0.0145, Val Loss: 0.3979
# Epoch 230, Train Loss: 0.0138, Val Loss: 0.3846
# Epoch 231, Train Loss: 0.0142, Val Loss: 0.3925
# Epoch 232, Train Loss: 0.0137, Val Loss: 0.3892
# Epoch 233, Train Loss: 0.0128, Val Loss: 0.3867
# Epoch 234, Train Loss: 0.0146, Val Loss: 0.3906
# Epoch 235, Train Loss: 0.0126, Val Loss: 0.3888
# Epoch 236, Train Loss: 0.0126, Val Loss: 0.3919
# Epoch 237, Train Loss: 0.0121, Val Loss: 0.3868
# Epoch 238, Train Loss: 0.0114, Val Loss: 0.3856
# Epoch 239, Train Loss: 0.0121, Val Loss: 0.3877
# Epoch 240, Train Loss: 0.0127, Val Loss: 0.3872
# Epoch 241, Train Loss: 0.0113, Val Loss: 0.3814
# Epoch 242, Train Loss: 0.0114, Val Loss: 0.3875
# Epoch 243, Train Loss: 0.0115, Val Loss: 0.3943
# Epoch 244, Train Loss: 0.0125, Val Loss: 0.3935
# Epoch 245, Train Loss: 0.0123, Val Loss: 0.3841
# Epoch 246, Train Loss: 0.0114, Val Loss: 0.3882
# Epoch 247, Train Loss: 0.0113, Val Loss: 0.3859
# Epoch 248, Train Loss: 0.0121, Val Loss: 0.3869
# Epoch 249, Train Loss: 0.0111, Val Loss: 0.3847
# Epoch 250, Train Loss: 0.0107, Val Loss: 0.3836
# Epoch 251, Train Loss: 0.0110, Val Loss: 0.3845
# Epoch 252, Train Loss: 0.0107, Val Loss: 0.3873
# Epoch 253, Train Loss: 0.0121, Val Loss: 0.3836
# Epoch 254, Train Loss: 0.0132, Val Loss: 0.3928
# Epoch 255, Train Loss: 0.0125, Val Loss: 0.3832
# Epoch 256, Train Loss: 0.0113, Val Loss: 0.3769
# Epoch 257, Train Loss: 0.0117, Val Loss: 0.3827
# Epoch 258, Train Loss: 0.0116, Val Loss: 0.3835
# Epoch 259, Train Loss: 0.0114, Val Loss: 0.3823
# Epoch 260, Train Loss: 0.0094, Val Loss: 0.3819
# Epoch 261, Train Loss: 0.0096, Val Loss: 0.3870
# Epoch 262, Train Loss: 0.0108, Val Loss: 0.3899
# Epoch 263, Train Loss: 0.0116, Val Loss: 0.3846
# Epoch 264, Train Loss: 0.0128, Val Loss: 0.3907
# Epoch 265, Train Loss: 0.0142, Val Loss: 0.3770
# Epoch 266, Train Loss: 0.0119, Val Loss: 0.3840
# Epoch 267, Train Loss: 0.0115, Val Loss: 0.3808
# Epoch 268, Train Loss: 0.0106, Val Loss: 0.3847
# Epoch 269, Train Loss: 0.0108, Val Loss: 0.3994
# Epoch 270, Train Loss: 0.0125, Val Loss: 0.3834
# Epoch 271, Train Loss: 0.0117, Val Loss: 0.3861
# Epoch 272, Train Loss: 0.0112, Val Loss: 0.3846
# Epoch 273, Train Loss: 0.0104, Val Loss: 0.3898
# Epoch 274, Train Loss: 0.0133, Val Loss: 0.3809
# Epoch 275, Train Loss: 0.0123, Val Loss: 0.3802
# Epoch 276, Train Loss: 0.0123, Val Loss: 0.3844
# Epoch 277, Train Loss: 0.0122, Val Loss: 0.3806
# Epoch 278, Train Loss: 0.0122, Val Loss: 0.3784
# Epoch 279, Train Loss: 0.0108, Val Loss: 0.3793
# Epoch 280, Train Loss: 0.0096, Val Loss: 0.3817
# Epoch 281, Train Loss: 0.0102, Val Loss: 0.3822
# Epoch 282, Train Loss: 0.0172, Val Loss: 0.3839
# Epoch 283, Train Loss: 0.0164, Val Loss: 0.3872
# Epoch 284, Train Loss: 0.0147, Val Loss: 0.3872
# Epoch 285, Train Loss: 0.0131, Val Loss: 0.3860
# Epoch 286, Train Loss: 0.0109, Val Loss: 0.3829
# Epoch 287, Train Loss: 0.0114, Val Loss: 0.3776
# Epoch 288, Train Loss: 0.0113, Val Loss: 0.3709
# Epoch 289, Train Loss: 0.0094, Val Loss: 0.3788
# Epoch 290, Train Loss: 0.0098, Val Loss: 0.3699
# Epoch 291, Train Loss: 0.0105, Val Loss: 0.3808
# Epoch 292, Train Loss: 0.0110, Val Loss: 0.3761
# Epoch 293, Train Loss: 0.0119, Val Loss: 0.3804
# Epoch 294, Train Loss: 0.0116, Val Loss: 0.3821
# Epoch 295, Train Loss: 0.0102, Val Loss: 0.3784
# Epoch 296, Train Loss: 0.0089, Val Loss: 0.3771
# Epoch 297, Train Loss: 0.0093, Val Loss: 0.3809
# Epoch 298, Train Loss: 0.0102, Val Loss: 0.3804
# Epoch 299, Train Loss: 0.0105, Val Loss: 0.3735
# Epoch 300, Train Loss: 0.0111, Val Loss: 0.3943
# Epoch 301, Train Loss: 0.0106, Val Loss: 0.3861
# Epoch 302, Train Loss: 0.0094, Val Loss: 0.3839
# Epoch 303, Train Loss: 0.0085, Val Loss: 0.3788
# Epoch 304, Train Loss: 0.0088, Val Loss: 0.3712
# Epoch 305, Train Loss: 0.0090, Val Loss: 0.3779
# Epoch 306, Train Loss: 0.0105, Val Loss: 0.3808
# Epoch 307, Train Loss: 0.0115, Val Loss: 0.3802
# Epoch 308, Train Loss: 0.0134, Val Loss: 0.3783
# Epoch 309, Train Loss: 0.0217, Val Loss: 0.3962
# Epoch 310, Train Loss: 0.0454, Val Loss: 0.5383
# Epoch 311, Train Loss: 0.4776, Val Loss: 1.1687
# Epoch 312, Train Loss: 0.7760, Val Loss: 0.9016
# Epoch 313, Train Loss: 0.4732, Val Loss: 0.6082
# Epoch 314, Train Loss: 0.3164, Val Loss: 0.5025
# Epoch 315, Train Loss: 0.2301, Val Loss: 0.5234
# Epoch 316, Train Loss: 0.1493, Val Loss: 0.4653
# Epoch 317, Train Loss: 0.1186, Val Loss: 0.4488
# Epoch 318, Train Loss: 0.0902, Val Loss: 0.4343
# Epoch 319, Train Loss: 0.0728, Val Loss: 0.4239
# Epoch 320, Train Loss: 0.0570, Val Loss: 0.4388
# Epoch 321, Train Loss: 0.0499, Val Loss: 0.4281
# Epoch 322, Train Loss: 0.0446, Val Loss: 0.4426
# Epoch 323, Train Loss: 0.0381, Val Loss: 0.4199
# Epoch 324, Train Loss: 0.0339, Val Loss: 0.4248
# Epoch 325, Train Loss: 0.0318, Val Loss: 0.4207
# Epoch 326, Train Loss: 0.0300, Val Loss: 0.4223
# Epoch 327, Train Loss: 0.0271, Val Loss: 0.4209
# Epoch 328, Train Loss: 0.0257, Val Loss: 0.4238
# Epoch 329, Train Loss: 0.0239, Val Loss: 0.4175
# Epoch 330, Train Loss: 0.0234, Val Loss: 0.4087
# Epoch 331, Train Loss: 0.0237, Val Loss: 0.4172
# Epoch 332, Train Loss: 0.0223, Val Loss: 0.4094
# Epoch 333, Train Loss: 0.0214, Val Loss: 0.4182
# Epoch 334, Train Loss: 0.0191, Val Loss: 0.4210
# Epoch 335, Train Loss: 0.0183, Val Loss: 0.4282
# Epoch 336, Train Loss: 0.0191, Val Loss: 0.4184
# Epoch 337, Train Loss: 0.0172, Val Loss: 0.4174
# Epoch 338, Train Loss: 0.0168, Val Loss: 0.4099
# Epoch 339, Train Loss: 0.0167, Val Loss: 0.4149
# Epoch 340, Train Loss: 0.0161, Val Loss: 0.4182
# Early stopping triggered.
# Top-4 markers Val Loss: 0.386612
#
#  Training with Top-5 markers: ['PSI', 'ASI', 'HEE', 'THAP', 'FMH']
# Loaded 2336 samples (using 5 markers)
# Loaded 292 samples (using 5 markers)
# Epoch 1, Train Loss: 3.6278, Val Loss: 2.7155
# Epoch 2, Train Loss: 2.1881, Val Loss: 2.2892
# Epoch 3, Train Loss: 1.9141, Val Loss: 2.1870
# Epoch 4, Train Loss: 1.7257, Val Loss: 2.0590
# Epoch 5, Train Loss: 1.5716, Val Loss: 1.8525
# Epoch 6, Train Loss: 1.4215, Val Loss: 1.7160
# Epoch 7, Train Loss: 1.3253, Val Loss: 1.9321
# Epoch 8, Train Loss: 1.3183, Val Loss: 1.7202
# Epoch 9, Train Loss: 1.2598, Val Loss: 1.6427
# Epoch 10, Train Loss: 1.0356, Val Loss: 1.3925
# Epoch 11, Train Loss: 0.9315, Val Loss: 1.3131
# Epoch 12, Train Loss: 0.8988, Val Loss: 1.2613
# Epoch 13, Train Loss: 0.9021, Val Loss: 1.2163
# Epoch 14, Train Loss: 0.9809, Val Loss: 1.0713
# Epoch 15, Train Loss: 0.7678, Val Loss: 1.0477
# Epoch 16, Train Loss: 0.7144, Val Loss: 0.9667
# Epoch 17, Train Loss: 0.6915, Val Loss: 0.9884
# Epoch 18, Train Loss: 0.7054, Val Loss: 0.8296
# Epoch 19, Train Loss: 0.7085, Val Loss: 0.8376
# Epoch 20, Train Loss: 0.5906, Val Loss: 0.7932
# Epoch 21, Train Loss: 0.5942, Val Loss: 0.7753
# Epoch 22, Train Loss: 0.5906, Val Loss: 0.7767
# Epoch 23, Train Loss: 0.4865, Val Loss: 0.6950
# Epoch 24, Train Loss: 0.5012, Val Loss: 0.6602
# Epoch 25, Train Loss: 0.4688, Val Loss: 0.7480
# Epoch 26, Train Loss: 0.4234, Val Loss: 0.6463
# Epoch 27, Train Loss: 0.4479, Val Loss: 0.6331
# Epoch 28, Train Loss: 0.4255, Val Loss: 0.6462
# Epoch 29, Train Loss: 0.3750, Val Loss: 0.5565
# Epoch 30, Train Loss: 0.3547, Val Loss: 0.5531
# Epoch 31, Train Loss: 0.3371, Val Loss: 0.5620
# Epoch 32, Train Loss: 0.3405, Val Loss: 0.5511
# Epoch 33, Train Loss: 0.3015, Val Loss: 0.5356
# Epoch 34, Train Loss: 0.3040, Val Loss: 0.5510
# Epoch 35, Train Loss: 0.2971, Val Loss: 0.5659
# Epoch 36, Train Loss: 0.3056, Val Loss: 0.5855
# Epoch 37, Train Loss: 0.3375, Val Loss: 0.5755
# Epoch 38, Train Loss: 0.2991, Val Loss: 0.5970
# Epoch 39, Train Loss: 0.2914, Val Loss: 0.8009
# Epoch 40, Train Loss: 0.3080, Val Loss: 0.5763
# Epoch 41, Train Loss: 0.3397, Val Loss: 0.5374
# Epoch 42, Train Loss: 0.2760, Val Loss: 0.5234
# Epoch 43, Train Loss: 0.2415, Val Loss: 0.6010
# Epoch 44, Train Loss: 0.2502, Val Loss: 0.5582
# Epoch 45, Train Loss: 0.2104, Val Loss: 0.4919
# Epoch 46, Train Loss: 0.1853, Val Loss: 0.5099
# Epoch 47, Train Loss: 0.1913, Val Loss: 0.5014
# Epoch 48, Train Loss: 0.1916, Val Loss: 0.4722
# Epoch 49, Train Loss: 0.1788, Val Loss: 0.5157
# Epoch 50, Train Loss: 0.1619, Val Loss: 0.5323
# Epoch 51, Train Loss: 0.1679, Val Loss: 0.4805
# Epoch 52, Train Loss: 0.1783, Val Loss: 0.4847
# Epoch 53, Train Loss: 0.1651, Val Loss: 0.5018
# Epoch 54, Train Loss: 0.1537, Val Loss: 0.5033
# Epoch 55, Train Loss: 0.1513, Val Loss: 0.4860
# Epoch 56, Train Loss: 0.1344, Val Loss: 0.4908
# Epoch 57, Train Loss: 0.1367, Val Loss: 0.4706
# Epoch 58, Train Loss: 0.1363, Val Loss: 0.4960
# Epoch 59, Train Loss: 0.1280, Val Loss: 0.4534
# Epoch 60, Train Loss: 0.1243, Val Loss: 0.5183
# Epoch 61, Train Loss: 0.1409, Val Loss: 0.5350
# Epoch 62, Train Loss: 0.1316, Val Loss: 0.4835
# Epoch 63, Train Loss: 0.1184, Val Loss: 0.4681
# Epoch 64, Train Loss: 0.1080, Val Loss: 0.4895
# Epoch 65, Train Loss: 0.1135, Val Loss: 0.4681
# Epoch 66, Train Loss: 0.1037, Val Loss: 0.4671
# Epoch 67, Train Loss: 0.1007, Val Loss: 0.5075
# Epoch 68, Train Loss: 0.1012, Val Loss: 0.5348
# Epoch 69, Train Loss: 0.1054, Val Loss: 0.4721
# Epoch 70, Train Loss: 0.1073, Val Loss: 0.4920
# Epoch 71, Train Loss: 0.1213, Val Loss: 0.5414
# Epoch 72, Train Loss: 0.1184, Val Loss: 0.4561
# Epoch 73, Train Loss: 0.1136, Val Loss: 0.5178
# Epoch 74, Train Loss: 0.1158, Val Loss: 0.4496
# Epoch 75, Train Loss: 0.0892, Val Loss: 0.4568
# Epoch 76, Train Loss: 0.0873, Val Loss: 0.4388
# Epoch 77, Train Loss: 0.0880, Val Loss: 0.4446
# Epoch 78, Train Loss: 0.0819, Val Loss: 0.4785
# Epoch 79, Train Loss: 0.0789, Val Loss: 0.4240
# Epoch 80, Train Loss: 0.0719, Val Loss: 0.4574
# Epoch 81, Train Loss: 0.0713, Val Loss: 0.4456
# Epoch 82, Train Loss: 0.0825, Val Loss: 0.4468
# Epoch 83, Train Loss: 0.0776, Val Loss: 0.4375
# Epoch 84, Train Loss: 0.0698, Val Loss: 0.4516
# Epoch 85, Train Loss: 0.0650, Val Loss: 0.4434
# Epoch 86, Train Loss: 0.0639, Val Loss: 0.4145
# Epoch 87, Train Loss: 0.0618, Val Loss: 0.4339
# Epoch 88, Train Loss: 0.0629, Val Loss: 0.4625
# Epoch 89, Train Loss: 0.0881, Val Loss: 0.4440
# Epoch 90, Train Loss: 0.0728, Val Loss: 0.4266
# Epoch 91, Train Loss: 0.0691, Val Loss: 0.4451
# Epoch 92, Train Loss: 0.0695, Val Loss: 0.4279
# Epoch 93, Train Loss: 0.0569, Val Loss: 0.4481
# Epoch 94, Train Loss: 0.0557, Val Loss: 0.4416
# Epoch 95, Train Loss: 0.0535, Val Loss: 0.4166
# Epoch 96, Train Loss: 0.0527, Val Loss: 0.4212
# Epoch 97, Train Loss: 0.0497, Val Loss: 0.4175
# Epoch 98, Train Loss: 0.0522, Val Loss: 0.4339
# Epoch 99, Train Loss: 0.0609, Val Loss: 0.4327
# Epoch 100, Train Loss: 0.0576, Val Loss: 0.4260
# Epoch 101, Train Loss: 0.0564, Val Loss: 0.4426
# Epoch 102, Train Loss: 0.0446, Val Loss: 0.4180
# Epoch 103, Train Loss: 0.0448, Val Loss: 0.4303
# Epoch 104, Train Loss: 0.0463, Val Loss: 0.4283
# Epoch 105, Train Loss: 0.0500, Val Loss: 0.4710
# Epoch 106, Train Loss: 0.0505, Val Loss: 0.4324
# Epoch 107, Train Loss: 0.0504, Val Loss: 0.4129
# Epoch 108, Train Loss: 0.0659, Val Loss: 0.4760
# Epoch 109, Train Loss: 0.1290, Val Loss: 0.5952
# Epoch 110, Train Loss: 0.1607, Val Loss: 0.5439
# Epoch 111, Train Loss: 0.1706, Val Loss: 0.5111
# Epoch 112, Train Loss: 0.1753, Val Loss: 0.4831
# Epoch 113, Train Loss: 0.1201, Val Loss: 0.4716
# Epoch 114, Train Loss: 0.1145, Val Loss: 0.5168
# Epoch 115, Train Loss: 0.0855, Val Loss: 0.4456
# Epoch 116, Train Loss: 0.0597, Val Loss: 0.4227
# Epoch 117, Train Loss: 0.0479, Val Loss: 0.4083
# Epoch 118, Train Loss: 0.0559, Val Loss: 0.4344
# Epoch 119, Train Loss: 0.0555, Val Loss: 0.4169
# Epoch 120, Train Loss: 0.0470, Val Loss: 0.4232
# Epoch 121, Train Loss: 0.0447, Val Loss: 0.4191
# Epoch 122, Train Loss: 0.0366, Val Loss: 0.4047
# Epoch 123, Train Loss: 0.0366, Val Loss: 0.4229
# Epoch 124, Train Loss: 0.0327, Val Loss: 0.4036
# Epoch 125, Train Loss: 0.0299, Val Loss: 0.4201
# Epoch 126, Train Loss: 0.0292, Val Loss: 0.4135
# Epoch 127, Train Loss: 0.0296, Val Loss: 0.4019
# Epoch 128, Train Loss: 0.0286, Val Loss: 0.4011
# Epoch 129, Train Loss: 0.0294, Val Loss: 0.3998
# Epoch 130, Train Loss: 0.0298, Val Loss: 0.4005
# Epoch 131, Train Loss: 0.0309, Val Loss: 0.4104
# Epoch 132, Train Loss: 0.0373, Val Loss: 0.4332
# Epoch 133, Train Loss: 0.0291, Val Loss: 0.4217
# Epoch 134, Train Loss: 0.0289, Val Loss: 0.4257
# Epoch 135, Train Loss: 0.0265, Val Loss: 0.4063
# Epoch 136, Train Loss: 0.0281, Val Loss: 0.4296
# Epoch 137, Train Loss: 0.0265, Val Loss: 0.4187
# Epoch 138, Train Loss: 0.0284, Val Loss: 0.3957
# Epoch 139, Train Loss: 0.0268, Val Loss: 0.4099
# Epoch 140, Train Loss: 0.0292, Val Loss: 0.4184
# Epoch 141, Train Loss: 0.0287, Val Loss: 0.4285
# Epoch 142, Train Loss: 0.0255, Val Loss: 0.4066
# Epoch 143, Train Loss: 0.0267, Val Loss: 0.4212
# Epoch 144, Train Loss: 0.0264, Val Loss: 0.4280
# Epoch 145, Train Loss: 0.0257, Val Loss: 0.4282
# Epoch 146, Train Loss: 0.0261, Val Loss: 0.4234
# Epoch 147, Train Loss: 0.0242, Val Loss: 0.4227
# Epoch 148, Train Loss: 0.0229, Val Loss: 0.4137
# Epoch 149, Train Loss: 0.0228, Val Loss: 0.4034
# Epoch 150, Train Loss: 0.0237, Val Loss: 0.4331
# Epoch 151, Train Loss: 0.0227, Val Loss: 0.4085
# Epoch 152, Train Loss: 0.0224, Val Loss: 0.4168
# Epoch 153, Train Loss: 0.0223, Val Loss: 0.3990
# Epoch 154, Train Loss: 0.0218, Val Loss: 0.4291
# Epoch 155, Train Loss: 0.0225, Val Loss: 0.4231
# Epoch 156, Train Loss: 0.0248, Val Loss: 0.4431
# Epoch 157, Train Loss: 0.0280, Val Loss: 0.4333
# Epoch 158, Train Loss: 0.0281, Val Loss: 0.4328
# Epoch 159, Train Loss: 0.0282, Val Loss: 0.4143
# Epoch 160, Train Loss: 0.0313, Val Loss: 0.4381
# Epoch 161, Train Loss: 0.0298, Val Loss: 0.4105
# Epoch 162, Train Loss: 0.0264, Val Loss: 0.4028
# Epoch 163, Train Loss: 0.0245, Val Loss: 0.4133
# Epoch 164, Train Loss: 0.0226, Val Loss: 0.4075
# Epoch 165, Train Loss: 0.0235, Val Loss: 0.4471
# Epoch 166, Train Loss: 0.0228, Val Loss: 0.4269
# Epoch 167, Train Loss: 0.0232, Val Loss: 0.4461
# Epoch 168, Train Loss: 0.0239, Val Loss: 0.4466
# Epoch 169, Train Loss: 0.0297, Val Loss: 0.4256
# Epoch 170, Train Loss: 0.0315, Val Loss: 0.4398
# Epoch 171, Train Loss: 0.0283, Val Loss: 0.4360
# Epoch 172, Train Loss: 0.0249, Val Loss: 0.4397
# Epoch 173, Train Loss: 0.0202, Val Loss: 0.4151
# Epoch 174, Train Loss: 0.0197, Val Loss: 0.4047
# Epoch 175, Train Loss: 0.0182, Val Loss: 0.4091
# Epoch 176, Train Loss: 0.0168, Val Loss: 0.4171
# Epoch 177, Train Loss: 0.0168, Val Loss: 0.4070
# Epoch 178, Train Loss: 0.0183, Val Loss: 0.4254
# Epoch 179, Train Loss: 0.0203, Val Loss: 0.4545
# Epoch 180, Train Loss: 0.0266, Val Loss: 0.4733
# Epoch 181, Train Loss: 0.0257, Val Loss: 0.4198
# Epoch 182, Train Loss: 0.0266, Val Loss: 0.4332
# Epoch 183, Train Loss: 0.0241, Val Loss: 0.4520
# Epoch 184, Train Loss: 0.0217, Val Loss: 0.4324
# Epoch 185, Train Loss: 0.0216, Val Loss: 0.4040
# Epoch 186, Train Loss: 0.0239, Val Loss: 0.4661
# Epoch 187, Train Loss: 0.0262, Val Loss: 0.4160
# Epoch 188, Train Loss: 0.0332, Val Loss: 0.4411
# Early stopping triggered.
# Top-5 markers Val Loss: 0.410612
#
#  Training with Top-6 markers: ['PSI', 'ASI', 'HEE', 'THAP', 'FMH', 'KNE']
# Loaded 2336 samples (using 6 markers)
# Loaded 292 samples (using 6 markers)
# Epoch 1, Train Loss: 3.8989, Val Loss: 3.0912
# Epoch 2, Train Loss: 2.3363, Val Loss: 2.5377
# Epoch 3, Train Loss: 1.9512, Val Loss: 2.2896
# Epoch 4, Train Loss: 1.6811, Val Loss: 1.9213
# Epoch 5, Train Loss: 1.6669, Val Loss: 2.5027
# Epoch 6, Train Loss: 1.5081, Val Loss: 1.7198
# Epoch 7, Train Loss: 1.2598, Val Loss: 1.6876
# Epoch 8, Train Loss: 1.2396, Val Loss: 1.6112
# Epoch 9, Train Loss: 1.1257, Val Loss: 1.2465
# Epoch 10, Train Loss: 0.9913, Val Loss: 1.0997
# Epoch 11, Train Loss: 1.0108, Val Loss: 1.0485
# Epoch 12, Train Loss: 0.8699, Val Loss: 1.1790
# Epoch 13, Train Loss: 0.9262, Val Loss: 1.1448
# Epoch 14, Train Loss: 0.8332, Val Loss: 0.9387
# Epoch 15, Train Loss: 0.7298, Val Loss: 0.9465
# Epoch 16, Train Loss: 0.6744, Val Loss: 0.9757
# Epoch 17, Train Loss: 0.7198, Val Loss: 0.9242
# Epoch 18, Train Loss: 0.6796, Val Loss: 0.9731
# Epoch 19, Train Loss: 0.6009, Val Loss: 0.7092
# Epoch 20, Train Loss: 0.6079, Val Loss: 0.7502
# Epoch 21, Train Loss: 0.5717, Val Loss: 0.7042
# Epoch 22, Train Loss: 0.5369, Val Loss: 0.6816
# Epoch 23, Train Loss: 0.5273, Val Loss: 0.7370
# Epoch 24, Train Loss: 0.5971, Val Loss: 1.2187
# Epoch 25, Train Loss: 0.5369, Val Loss: 0.7480
# Epoch 26, Train Loss: 0.4754, Val Loss: 0.6559
# Epoch 27, Train Loss: 0.5855, Val Loss: 0.7226
# Epoch 28, Train Loss: 0.4740, Val Loss: 0.6876
# Epoch 29, Train Loss: 0.4503, Val Loss: 0.6166
# Epoch 30, Train Loss: 0.4129, Val Loss: 0.7750
# Epoch 31, Train Loss: 0.4432, Val Loss: 0.6797
# Epoch 32, Train Loss: 0.3772, Val Loss: 0.5650
# Epoch 33, Train Loss: 0.3565, Val Loss: 0.5478
# Epoch 34, Train Loss: 0.3409, Val Loss: 0.5318
# Epoch 35, Train Loss: 0.3362, Val Loss: 0.6543
# Epoch 36, Train Loss: 0.3719, Val Loss: 0.6315
# Epoch 37, Train Loss: 0.3317, Val Loss: 0.5956
# Epoch 38, Train Loss: 0.3135, Val Loss: 0.6084
# Epoch 39, Train Loss: 0.3099, Val Loss: 0.6340
# Epoch 40, Train Loss: 0.2956, Val Loss: 0.4947
# Epoch 41, Train Loss: 0.2708, Val Loss: 0.5630
# Epoch 42, Train Loss: 0.3324, Val Loss: 0.5330
# Epoch 43, Train Loss: 0.2766, Val Loss: 0.4917
# Epoch 44, Train Loss: 0.2560, Val Loss: 0.5196
# Epoch 45, Train Loss: 0.2463, Val Loss: 0.5074
# Epoch 46, Train Loss: 0.2326, Val Loss: 0.5131
# Epoch 47, Train Loss: 0.2249, Val Loss: 0.4785
# Epoch 48, Train Loss: 0.2073, Val Loss: 0.4985
# Epoch 49, Train Loss: 0.2056, Val Loss: 0.4914
# Epoch 50, Train Loss: 0.2024, Val Loss: 0.4693
# Epoch 51, Train Loss: 0.2006, Val Loss: 0.4985
# Epoch 52, Train Loss: 0.1903, Val Loss: 0.4576
# Epoch 53, Train Loss: 0.1818, Val Loss: 0.4676
# Epoch 54, Train Loss: 0.1684, Val Loss: 0.4566
# Epoch 55, Train Loss: 0.1659, Val Loss: 0.4998
# Epoch 56, Train Loss: 0.1852, Val Loss: 0.4715
# Epoch 57, Train Loss: 0.1854, Val Loss: 0.4800
# Epoch 58, Train Loss: 0.1636, Val Loss: 0.4968
# Epoch 59, Train Loss: 0.1716, Val Loss: 0.4563
# Epoch 60, Train Loss: 0.1656, Val Loss: 0.4764
# Epoch 61, Train Loss: 0.1494, Val Loss: 0.4371
# Epoch 62, Train Loss: 0.1329, Val Loss: 0.4541
# Epoch 63, Train Loss: 0.1282, Val Loss: 0.4321
# Epoch 64, Train Loss: 0.1685, Val Loss: 0.4715
# Epoch 65, Train Loss: 0.1431, Val Loss: 0.4434
# Epoch 66, Train Loss: 0.1243, Val Loss: 0.4389
# Epoch 67, Train Loss: 0.1133, Val Loss: 0.4418
# Epoch 68, Train Loss: 0.1136, Val Loss: 0.4324
# Epoch 69, Train Loss: 0.1048, Val Loss: 0.4423
# Epoch 70, Train Loss: 0.1073, Val Loss: 0.4207
# Epoch 71, Train Loss: 0.1104, Val Loss: 0.4443
# Epoch 72, Train Loss: 0.1047, Val Loss: 0.4650
# Epoch 73, Train Loss: 0.1466, Val Loss: 0.4678
# Epoch 74, Train Loss: 0.1145, Val Loss: 0.4519
# Epoch 75, Train Loss: 0.0995, Val Loss: 0.4372
# Epoch 76, Train Loss: 0.0958, Val Loss: 0.4404
# Epoch 77, Train Loss: 0.0955, Val Loss: 0.4716
# Epoch 78, Train Loss: 0.0923, Val Loss: 0.4453
# Epoch 79, Train Loss: 0.1095, Val Loss: 0.4589
# Epoch 80, Train Loss: 0.0916, Val Loss: 0.4370
# Epoch 81, Train Loss: 0.0924, Val Loss: 0.4130
# Epoch 82, Train Loss: 0.0893, Val Loss: 0.4399
# Epoch 83, Train Loss: 0.0814, Val Loss: 0.4222
# Epoch 84, Train Loss: 0.0765, Val Loss: 0.4118
# Epoch 85, Train Loss: 0.0712, Val Loss: 0.4599
# Epoch 86, Train Loss: 0.0719, Val Loss: 0.4325
# Epoch 87, Train Loss: 0.0821, Val Loss: 0.4577
# Epoch 88, Train Loss: 0.0908, Val Loss: 0.4313
# Epoch 89, Train Loss: 0.0835, Val Loss: 0.4108
# Epoch 90, Train Loss: 0.0632, Val Loss: 0.4413
# Epoch 91, Train Loss: 0.0603, Val Loss: 0.4332
# Epoch 92, Train Loss: 0.0790, Val Loss: 0.3997
# Epoch 93, Train Loss: 0.0637, Val Loss: 0.4627
# Epoch 94, Train Loss: 0.0676, Val Loss: 0.4337
# Epoch 95, Train Loss: 0.0573, Val Loss: 0.4309
# Epoch 96, Train Loss: 0.0573, Val Loss: 0.4383
# Epoch 97, Train Loss: 0.0575, Val Loss: 0.4342
# Epoch 98, Train Loss: 0.0530, Val Loss: 0.4272
# Epoch 99, Train Loss: 0.0531, Val Loss: 0.4344
# Epoch 100, Train Loss: 0.0544, Val Loss: 0.4406
# Epoch 101, Train Loss: 0.0672, Val Loss: 0.4092
# Epoch 102, Train Loss: 0.0550, Val Loss: 0.4219
# Epoch 103, Train Loss: 0.0507, Val Loss: 0.4385
# Epoch 104, Train Loss: 0.0542, Val Loss: 0.4126
# Epoch 105, Train Loss: 0.0536, Val Loss: 0.4104
# Epoch 106, Train Loss: 0.0463, Val Loss: 0.4056
# Epoch 107, Train Loss: 0.0506, Val Loss: 0.4080
# Epoch 108, Train Loss: 0.0538, Val Loss: 0.4032
# Epoch 109, Train Loss: 0.0503, Val Loss: 0.4368
# Epoch 110, Train Loss: 0.0483, Val Loss: 0.4446
# Epoch 111, Train Loss: 0.0544, Val Loss: 0.4145
# Epoch 112, Train Loss: 0.0505, Val Loss: 0.4222
# Epoch 113, Train Loss: 0.0476, Val Loss: 0.3978
# Epoch 114, Train Loss: 0.0525, Val Loss: 0.4364
# Epoch 115, Train Loss: 0.0561, Val Loss: 0.4115
# Epoch 116, Train Loss: 0.0518, Val Loss: 0.4060
# Epoch 117, Train Loss: 0.0463, Val Loss: 0.4152
# Epoch 118, Train Loss: 0.0430, Val Loss: 0.4074
# Epoch 119, Train Loss: 0.0404, Val Loss: 0.4196
# Epoch 120, Train Loss: 0.0353, Val Loss: 0.4192
# Epoch 121, Train Loss: 0.0375, Val Loss: 0.4189
# Epoch 122, Train Loss: 0.0352, Val Loss: 0.4220
# Epoch 123, Train Loss: 0.0353, Val Loss: 0.4168
# Epoch 124, Train Loss: 0.0374, Val Loss: 0.4377
# Epoch 125, Train Loss: 0.0338, Val Loss: 0.4154
# Epoch 126, Train Loss: 0.0339, Val Loss: 0.4640
# Epoch 127, Train Loss: 0.0502, Val Loss: 0.4236
# Epoch 128, Train Loss: 0.0413, Val Loss: 0.4380
# Epoch 129, Train Loss: 0.0512, Val Loss: 0.4761
# Epoch 130, Train Loss: 0.0505, Val Loss: 0.4361
# Epoch 131, Train Loss: 0.0535, Val Loss: 0.4506
# Epoch 132, Train Loss: 0.0399, Val Loss: 0.4429
# Epoch 133, Train Loss: 0.0475, Val Loss: 0.4473
# Epoch 134, Train Loss: 0.0459, Val Loss: 0.4158
# Epoch 135, Train Loss: 0.0421, Val Loss: 0.4300
# Epoch 136, Train Loss: 0.0388, Val Loss: 0.4266
# Epoch 137, Train Loss: 0.0441, Val Loss: 0.4209
# Epoch 138, Train Loss: 0.0464, Val Loss: 0.4252
# Epoch 139, Train Loss: 0.0372, Val Loss: 0.4280
# Epoch 140, Train Loss: 0.0331, Val Loss: 0.4354
# Epoch 141, Train Loss: 0.0441, Val Loss: 0.4428
# Epoch 142, Train Loss: 0.0467, Val Loss: 0.4469
# Epoch 143, Train Loss: 0.0457, Val Loss: 0.4259
# Epoch 144, Train Loss: 0.0390, Val Loss: 0.4098
# Epoch 145, Train Loss: 0.0319, Val Loss: 0.4029
# Epoch 146, Train Loss: 0.0325, Val Loss: 0.4136
# Epoch 147, Train Loss: 0.1495, Val Loss: 1.5699
# Epoch 148, Train Loss: 1.2163, Val Loss: 1.3196
# Epoch 149, Train Loss: 0.9642, Val Loss: 0.8097
# Epoch 150, Train Loss: 0.7424, Val Loss: 0.8902
# Epoch 151, Train Loss: 0.5487, Val Loss: 0.6351
# Epoch 152, Train Loss: 0.4368, Val Loss: 0.5685
# Epoch 153, Train Loss: 0.3093, Val Loss: 0.5233
# Epoch 154, Train Loss: 0.2373, Val Loss: 0.4407
# Epoch 155, Train Loss: 0.1994, Val Loss: 0.4332
# Epoch 156, Train Loss: 0.1707, Val Loss: 0.4490
# Epoch 157, Train Loss: 0.1651, Val Loss: 0.4621
# Epoch 158, Train Loss: 0.1440, Val Loss: 0.4112
# Epoch 159, Train Loss: 0.1218, Val Loss: 0.4396
# Epoch 160, Train Loss: 0.1136, Val Loss: 0.3922
# Epoch 161, Train Loss: 0.1037, Val Loss: 0.3831
# Epoch 162, Train Loss: 0.0918, Val Loss: 0.3852
# Epoch 163, Train Loss: 0.0773, Val Loss: 0.3864
# Epoch 164, Train Loss: 0.0697, Val Loss: 0.3862
# Epoch 165, Train Loss: 0.0646, Val Loss: 0.3938
# Epoch 166, Train Loss: 0.0583, Val Loss: 0.3735
# Epoch 167, Train Loss: 0.0539, Val Loss: 0.3631
# Epoch 168, Train Loss: 0.0491, Val Loss: 0.3693
# Epoch 169, Train Loss: 0.0485, Val Loss: 0.3823
# Epoch 170, Train Loss: 0.0484, Val Loss: 0.3675
# Epoch 171, Train Loss: 0.0430, Val Loss: 0.3827
# Epoch 172, Train Loss: 0.0392, Val Loss: 0.3818
# Epoch 173, Train Loss: 0.0395, Val Loss: 0.3711
# Epoch 174, Train Loss: 0.0366, Val Loss: 0.3592
# Epoch 175, Train Loss: 0.0394, Val Loss: 0.3711
# Epoch 176, Train Loss: 0.0396, Val Loss: 0.3818
# Epoch 177, Train Loss: 0.0435, Val Loss: 0.3789
# Epoch 178, Train Loss: 0.0355, Val Loss: 0.3705
# Epoch 179, Train Loss: 0.0364, Val Loss: 0.3817
# Epoch 180, Train Loss: 0.0334, Val Loss: 0.3714
# Epoch 181, Train Loss: 0.0312, Val Loss: 0.3724
# Epoch 182, Train Loss: 0.0332, Val Loss: 0.3656
# Epoch 183, Train Loss: 0.0295, Val Loss: 0.3702
# Epoch 184, Train Loss: 0.0309, Val Loss: 0.3675
# Epoch 185, Train Loss: 0.0296, Val Loss: 0.3697
# Epoch 186, Train Loss: 0.0268, Val Loss: 0.3704
# Epoch 187, Train Loss: 0.0266, Val Loss: 0.3748
# Epoch 188, Train Loss: 0.0266, Val Loss: 0.3652
# Epoch 189, Train Loss: 0.0267, Val Loss: 0.3612
# Epoch 190, Train Loss: 0.0269, Val Loss: 0.3636
# Epoch 191, Train Loss: 0.0276, Val Loss: 0.3700
# Epoch 192, Train Loss: 0.0287, Val Loss: 0.3712
# Epoch 193, Train Loss: 0.0299, Val Loss: 0.3736
# Epoch 194, Train Loss: 0.0257, Val Loss: 0.3722
# Epoch 195, Train Loss: 0.0248, Val Loss: 0.3668
# Epoch 196, Train Loss: 0.0245, Val Loss: 0.3668
# Epoch 197, Train Loss: 0.0228, Val Loss: 0.3619
# Epoch 198, Train Loss: 0.0232, Val Loss: 0.3695
# Epoch 199, Train Loss: 0.0302, Val Loss: 0.3665
# Epoch 200, Train Loss: 0.0355, Val Loss: 0.3758
# Epoch 201, Train Loss: 0.0291, Val Loss: 0.3598
# Epoch 202, Train Loss: 0.0252, Val Loss: 0.3639
# Epoch 203, Train Loss: 0.0250, Val Loss: 0.3568
# Epoch 204, Train Loss: 0.0235, Val Loss: 0.3734
# Epoch 205, Train Loss: 0.0270, Val Loss: 0.3724
# Epoch 206, Train Loss: 0.0238, Val Loss: 0.3644
# Epoch 207, Train Loss: 0.0213, Val Loss: 0.3750
# Epoch 208, Train Loss: 0.0212, Val Loss: 0.3806
# Epoch 209, Train Loss: 0.0228, Val Loss: 0.3689
# Epoch 210, Train Loss: 0.0193, Val Loss: 0.3657
# Epoch 211, Train Loss: 0.0231, Val Loss: 0.3802
# Epoch 212, Train Loss: 0.0231, Val Loss: 0.3754
# Epoch 213, Train Loss: 0.0236, Val Loss: 0.3722
# Epoch 214, Train Loss: 0.0230, Val Loss: 0.3748
# Epoch 215, Train Loss: 0.0213, Val Loss: 0.3716
# Epoch 216, Train Loss: 0.0197, Val Loss: 0.3686
# Epoch 217, Train Loss: 0.0188, Val Loss: 0.3733
# Epoch 218, Train Loss: 0.0188, Val Loss: 0.3628
# Epoch 219, Train Loss: 0.0223, Val Loss: 0.3661
# Epoch 220, Train Loss: 0.0275, Val Loss: 0.3905
# Epoch 221, Train Loss: 0.0284, Val Loss: 0.3689
# Epoch 222, Train Loss: 0.0261, Val Loss: 0.3775
# Epoch 223, Train Loss: 0.0370, Val Loss: 0.4167
# Epoch 224, Train Loss: 0.1609, Val Loss: 0.5377
# Epoch 225, Train Loss: 0.3388, Val Loss: 0.7835
# Epoch 226, Train Loss: 0.3423, Val Loss: 0.5408
# Epoch 227, Train Loss: 0.2142, Val Loss: 0.5006
# Epoch 228, Train Loss: 0.1360, Val Loss: 0.4204
# Epoch 229, Train Loss: 0.0805, Val Loss: 0.3939
# Epoch 230, Train Loss: 0.0521, Val Loss: 0.3814
# Epoch 231, Train Loss: 0.0405, Val Loss: 0.3754
# Epoch 232, Train Loss: 0.0342, Val Loss: 0.3790
# Epoch 233, Train Loss: 0.0312, Val Loss: 0.3725
# Epoch 234, Train Loss: 0.0274, Val Loss: 0.3719
# Epoch 235, Train Loss: 0.0255, Val Loss: 0.3723
# Epoch 236, Train Loss: 0.0233, Val Loss: 0.3733
# Epoch 237, Train Loss: 0.0223, Val Loss: 0.3651
# Epoch 238, Train Loss: 0.0223, Val Loss: 0.3804
# Epoch 239, Train Loss: 0.0207, Val Loss: 0.3685
# Epoch 240, Train Loss: 0.0192, Val Loss: 0.3644
# Epoch 241, Train Loss: 0.0200, Val Loss: 0.3731
# Epoch 242, Train Loss: 0.0212, Val Loss: 0.3674
# Epoch 243, Train Loss: 0.0185, Val Loss: 0.3669
# Epoch 244, Train Loss: 0.0175, Val Loss: 0.3720
# Epoch 245, Train Loss: 0.0166, Val Loss: 0.3673
# Epoch 246, Train Loss: 0.0170, Val Loss: 0.3701
# Epoch 247, Train Loss: 0.0174, Val Loss: 0.3697
# Epoch 248, Train Loss: 0.0161, Val Loss: 0.3667
# Epoch 249, Train Loss: 0.0143, Val Loss: 0.3671
# Epoch 250, Train Loss: 0.0148, Val Loss: 0.3595
# Epoch 251, Train Loss: 0.0149, Val Loss: 0.3636
# Epoch 252, Train Loss: 0.0148, Val Loss: 0.3598
# Epoch 253, Train Loss: 0.0144, Val Loss: 0.3675
# Early stopping triggered.
# Top-6 markers Val Loss: 0.364483
#
#  Training with Top-7 markers: ['PSI', 'ASI', 'HEE', 'THAP', 'FMH', 'KNE', 'VMH']
# Loaded 2336 samples (using 7 markers)
# Loaded 292 samples (using 7 markers)
# Epoch 1, Train Loss: 3.6802, Val Loss: 2.7163
# Epoch 2, Train Loss: 2.2538, Val Loss: 2.3370
# Epoch 3, Train Loss: 1.9651, Val Loss: 2.0832
# Epoch 4, Train Loss: 1.9036, Val Loss: 2.1544
# Epoch 5, Train Loss: 1.7346, Val Loss: 1.8820
# Epoch 6, Train Loss: 1.4823, Val Loss: 1.7682
# Epoch 7, Train Loss: 1.3920, Val Loss: 1.8345
# Epoch 8, Train Loss: 1.2830, Val Loss: 1.9365
# Epoch 9, Train Loss: 1.2194, Val Loss: 1.5286
# Epoch 10, Train Loss: 1.0964, Val Loss: 1.3021
# Epoch 11, Train Loss: 1.0751, Val Loss: 1.2500
# Epoch 12, Train Loss: 1.0900, Val Loss: 1.2228
# Epoch 13, Train Loss: 1.0083, Val Loss: 1.1565
# Epoch 14, Train Loss: 0.9074, Val Loss: 1.0520
# Epoch 15, Train Loss: 0.8459, Val Loss: 0.9970
# Epoch 16, Train Loss: 0.7609, Val Loss: 0.9372
# Epoch 17, Train Loss: 0.8256, Val Loss: 1.0867
# Epoch 18, Train Loss: 0.8895, Val Loss: 0.9425
# Epoch 19, Train Loss: 0.7293, Val Loss: 0.8914
# Epoch 20, Train Loss: 0.6608, Val Loss: 0.9661
# Epoch 21, Train Loss: 0.6429, Val Loss: 0.8957
# Epoch 22, Train Loss: 0.6374, Val Loss: 0.8056
# Epoch 23, Train Loss: 0.6080, Val Loss: 0.7230
# Epoch 24, Train Loss: 0.6893, Val Loss: 0.8362
# Epoch 25, Train Loss: 0.6429, Val Loss: 0.8849
# Epoch 26, Train Loss: 0.5317, Val Loss: 0.7338
# Epoch 27, Train Loss: 0.4906, Val Loss: 0.6911
# Epoch 28, Train Loss: 0.4585, Val Loss: 0.6744
# Epoch 29, Train Loss: 0.4462, Val Loss: 0.6311
# Epoch 30, Train Loss: 0.4434, Val Loss: 0.6412
# Epoch 31, Train Loss: 0.4166, Val Loss: 0.7774
# Epoch 32, Train Loss: 0.3974, Val Loss: 0.5996
# Epoch 33, Train Loss: 0.3812, Val Loss: 0.5671
# Epoch 34, Train Loss: 0.3865, Val Loss: 0.6467
# Epoch 35, Train Loss: 0.3837, Val Loss: 0.7203
# Epoch 36, Train Loss: 0.3829, Val Loss: 0.5575
# Epoch 37, Train Loss: 0.3539, Val Loss: 0.5635
# Epoch 38, Train Loss: 0.3356, Val Loss: 0.5714
# Epoch 39, Train Loss: 0.3496, Val Loss: 0.6203
# Epoch 40, Train Loss: 0.3276, Val Loss: 0.5431
# Epoch 41, Train Loss: 0.2827, Val Loss: 0.5636
# Epoch 42, Train Loss: 0.2747, Val Loss: 0.6215
# Epoch 43, Train Loss: 0.3004, Val Loss: 0.5384
# Epoch 44, Train Loss: 0.2539, Val Loss: 0.5171
# Epoch 45, Train Loss: 0.2447, Val Loss: 0.7088
# Epoch 46, Train Loss: 0.2819, Val Loss: 0.5402
# Epoch 47, Train Loss: 0.2526, Val Loss: 0.6130
# Epoch 48, Train Loss: 0.2385, Val Loss: 0.5132
# Epoch 49, Train Loss: 0.2098, Val Loss: 0.5327
# Epoch 50, Train Loss: 0.2192, Val Loss: 0.5803
# Epoch 51, Train Loss: 0.2309, Val Loss: 0.5385
# Epoch 52, Train Loss: 0.1968, Val Loss: 0.5172
# Epoch 53, Train Loss: 0.2016, Val Loss: 0.4996
# Epoch 54, Train Loss: 0.2256, Val Loss: 0.5353
# Epoch 55, Train Loss: 0.2245, Val Loss: 0.5171
# Epoch 56, Train Loss: 0.1899, Val Loss: 0.4671
# Epoch 57, Train Loss: 0.1853, Val Loss: 0.4823
# Epoch 58, Train Loss: 0.1718, Val Loss: 0.4495
# Epoch 59, Train Loss: 0.1643, Val Loss: 0.5053
# Epoch 60, Train Loss: 0.1592, Val Loss: 0.5026
# Epoch 61, Train Loss: 0.1447, Val Loss: 0.4608
# Epoch 62, Train Loss: 0.1309, Val Loss: 0.4787
# Epoch 63, Train Loss: 0.1301, Val Loss: 0.4616
# Epoch 64, Train Loss: 0.1287, Val Loss: 0.4506
# Epoch 65, Train Loss: 0.1286, Val Loss: 0.4545
# Epoch 66, Train Loss: 0.1307, Val Loss: 0.4910
# Epoch 67, Train Loss: 0.1208, Val Loss: 0.4424
# Epoch 68, Train Loss: 0.1072, Val Loss: 0.4561
# Epoch 69, Train Loss: 0.1098, Val Loss: 0.4901
# Epoch 70, Train Loss: 0.1120, Val Loss: 0.4469
# Epoch 71, Train Loss: 0.1015, Val Loss: 0.4318
# Epoch 72, Train Loss: 0.1023, Val Loss: 0.4499
# Epoch 73, Train Loss: 0.1019, Val Loss: 0.4660
# Epoch 74, Train Loss: 0.1075, Val Loss: 0.4605
# Epoch 75, Train Loss: 0.1068, Val Loss: 0.4702
# Epoch 76, Train Loss: 0.1156, Val Loss: 0.4718
# Epoch 77, Train Loss: 0.1064, Val Loss: 0.4531
# Epoch 78, Train Loss: 0.1014, Val Loss: 0.5683
# Epoch 79, Train Loss: 0.1742, Val Loss: 0.5698
# Epoch 80, Train Loss: 0.2513, Val Loss: 0.5062
# Epoch 81, Train Loss: 0.1620, Val Loss: 0.5211
# Epoch 82, Train Loss: 0.1161, Val Loss: 0.4684
# Epoch 83, Train Loss: 0.0984, Val Loss: 0.4557
# Epoch 84, Train Loss: 0.0841, Val Loss: 0.4321
# Epoch 85, Train Loss: 0.0806, Val Loss: 0.4619
# Epoch 86, Train Loss: 0.0722, Val Loss: 0.4324
# Epoch 87, Train Loss: 0.0669, Val Loss: 0.4458
# Epoch 88, Train Loss: 0.0770, Val Loss: 0.4280
# Epoch 89, Train Loss: 0.0662, Val Loss: 0.4276
# Epoch 90, Train Loss: 0.0633, Val Loss: 0.4448
# Epoch 91, Train Loss: 0.0669, Val Loss: 0.4425
# Epoch 92, Train Loss: 0.0643, Val Loss: 0.4543
# Epoch 93, Train Loss: 0.0623, Val Loss: 0.4550
# Epoch 94, Train Loss: 0.0599, Val Loss: 0.4584
# Epoch 95, Train Loss: 0.0652, Val Loss: 0.4664
# Epoch 96, Train Loss: 0.0627, Val Loss: 0.4502
# Epoch 97, Train Loss: 0.0544, Val Loss: 0.4428
# Epoch 98, Train Loss: 0.0535, Val Loss: 0.4474
# Epoch 99, Train Loss: 0.0579, Val Loss: 0.4374
# Epoch 100, Train Loss: 0.0588, Val Loss: 0.4537
# Epoch 101, Train Loss: 0.0569, Val Loss: 0.4483
# Epoch 102, Train Loss: 0.0516, Val Loss: 0.4367
# Epoch 103, Train Loss: 0.0507, Val Loss: 0.4604
# Epoch 104, Train Loss: 0.0518, Val Loss: 0.4428
# Epoch 105, Train Loss: 0.0468, Val Loss: 0.4454
# Epoch 106, Train Loss: 0.0467, Val Loss: 0.4343
# Epoch 107, Train Loss: 0.0563, Val Loss: 0.4445
# Epoch 108, Train Loss: 0.0539, Val Loss: 0.4476
# Epoch 109, Train Loss: 0.0451, Val Loss: 0.4378
# Epoch 110, Train Loss: 0.0464, Val Loss: 0.4448
# Epoch 111, Train Loss: 0.0462, Val Loss: 0.4421
# Epoch 112, Train Loss: 0.0462, Val Loss: 0.4138
# Epoch 113, Train Loss: 0.0465, Val Loss: 0.4597
# Epoch 114, Train Loss: 0.0417, Val Loss: 0.4425
# Epoch 115, Train Loss: 0.0499, Val Loss: 0.4692
# Epoch 116, Train Loss: 0.0457, Val Loss: 0.4547
# Epoch 117, Train Loss: 0.0493, Val Loss: 0.4289
# Epoch 118, Train Loss: 0.0468, Val Loss: 0.4394
# Epoch 119, Train Loss: 0.0756, Val Loss: 0.4814
# Epoch 120, Train Loss: 0.0953, Val Loss: 0.4526
# Epoch 121, Train Loss: 0.0712, Val Loss: 0.4962
# Epoch 122, Train Loss: 0.1985, Val Loss: 0.6389
# Epoch 123, Train Loss: 0.2644, Val Loss: 0.6134
# Epoch 124, Train Loss: 0.2724, Val Loss: 0.6469
# Epoch 125, Train Loss: 0.2990, Val Loss: 0.6163
# Epoch 126, Train Loss: 0.2603, Val Loss: 0.6396
# Epoch 127, Train Loss: 0.1762, Val Loss: 0.5035
# Epoch 128, Train Loss: 0.1009, Val Loss: 0.4368
# Epoch 129, Train Loss: 0.0734, Val Loss: 0.4822
# Epoch 130, Train Loss: 0.0559, Val Loss: 0.4329
# Epoch 131, Train Loss: 0.0476, Val Loss: 0.4260
# Epoch 132, Train Loss: 0.0446, Val Loss: 0.4275
# Epoch 133, Train Loss: 0.0382, Val Loss: 0.4408
# Epoch 134, Train Loss: 0.0368, Val Loss: 0.4403
# Epoch 135, Train Loss: 0.0351, Val Loss: 0.4393
# Epoch 136, Train Loss: 0.0353, Val Loss: 0.4403
# Epoch 137, Train Loss: 0.0331, Val Loss: 0.4267
# Epoch 138, Train Loss: 0.0329, Val Loss: 0.4420
# Epoch 139, Train Loss: 0.0325, Val Loss: 0.4363
# Epoch 140, Train Loss: 0.0314, Val Loss: 0.4216
# Epoch 141, Train Loss: 0.0297, Val Loss: 0.4558
# Epoch 142, Train Loss: 0.0317, Val Loss: 0.4470
# Epoch 143, Train Loss: 0.0308, Val Loss: 0.4381
# Epoch 144, Train Loss: 0.0306, Val Loss: 0.4476
# Epoch 145, Train Loss: 0.0275, Val Loss: 0.4434
# Epoch 146, Train Loss: 0.0262, Val Loss: 0.4262
# Epoch 147, Train Loss: 0.0273, Val Loss: 0.4407
# Epoch 148, Train Loss: 0.0267, Val Loss: 0.4390
# Epoch 149, Train Loss: 0.0283, Val Loss: 0.4367
# Epoch 150, Train Loss: 0.0292, Val Loss: 0.4533
# Epoch 151, Train Loss: 0.0277, Val Loss: 0.4579
# Epoch 152, Train Loss: 0.0308, Val Loss: 0.4491
# Epoch 153, Train Loss: 0.0298, Val Loss: 0.4309
# Epoch 154, Train Loss: 0.0264, Val Loss: 0.4253
# Epoch 155, Train Loss: 0.0255, Val Loss: 0.4322
# Epoch 156, Train Loss: 0.0282, Val Loss: 0.4280
# Epoch 157, Train Loss: 0.0259, Val Loss: 0.4199
# Epoch 158, Train Loss: 0.0243, Val Loss: 0.4201
# Epoch 159, Train Loss: 0.0242, Val Loss: 0.4294
# Epoch 160, Train Loss: 0.0234, Val Loss: 0.4303
# Epoch 161, Train Loss: 0.0214, Val Loss: 0.4325
# Epoch 162, Train Loss: 0.0231, Val Loss: 0.4267
# Early stopping triggered.
# Top-7 markers Val Loss: 0.423553
#
#  Training with Top-8 markers: ['PSI', 'ASI', 'HEE', 'THAP', 'FMH', 'KNE', 'VMH', 'THAD']
# Loaded 2336 samples (using 8 markers)
# Loaded 292 samples (using 8 markers)
# Epoch 1, Train Loss: 3.5960, Val Loss: 3.0103
# Epoch 2, Train Loss: 2.3187, Val Loss: 2.4748
# Epoch 3, Train Loss: 2.0499, Val Loss: 2.1526
# Epoch 4, Train Loss: 1.7990, Val Loss: 1.9716
# Epoch 5, Train Loss: 1.5389, Val Loss: 1.8607
# Epoch 6, Train Loss: 1.5341, Val Loss: 1.9353
# Epoch 7, Train Loss: 1.4793, Val Loss: 2.1429
# Epoch 8, Train Loss: 1.3677, Val Loss: 1.5684
# Epoch 9, Train Loss: 1.1586, Val Loss: 1.2871
# Epoch 10, Train Loss: 1.1386, Val Loss: 1.3747
# Epoch 11, Train Loss: 1.0175, Val Loss: 1.2475
# Epoch 12, Train Loss: 1.0249, Val Loss: 1.5115
# Epoch 13, Train Loss: 0.9462, Val Loss: 1.0824
# Epoch 14, Train Loss: 0.8955, Val Loss: 0.9390
# Epoch 15, Train Loss: 0.8026, Val Loss: 1.0686
# Epoch 16, Train Loss: 0.7393, Val Loss: 0.8767
# Epoch 17, Train Loss: 0.7970, Val Loss: 1.0244
# Epoch 18, Train Loss: 0.8142, Val Loss: 1.0499
# Epoch 19, Train Loss: 0.6838, Val Loss: 0.8389
# Epoch 20, Train Loss: 0.6591, Val Loss: 0.8205
# Epoch 21, Train Loss: 0.5878, Val Loss: 0.7751
# Epoch 22, Train Loss: 0.5827, Val Loss: 0.8420
# Epoch 23, Train Loss: 0.5670, Val Loss: 0.8400
# Epoch 24, Train Loss: 0.5367, Val Loss: 0.7435
# Epoch 25, Train Loss: 0.5279, Val Loss: 0.7862
# Epoch 26, Train Loss: 0.4960, Val Loss: 0.6410
# Epoch 27, Train Loss: 0.4466, Val Loss: 0.6237
# Epoch 28, Train Loss: 0.4404, Val Loss: 0.5665
# Epoch 29, Train Loss: 0.4377, Val Loss: 0.6494
# Epoch 30, Train Loss: 0.4252, Val Loss: 0.5954
# Epoch 31, Train Loss: 0.3842, Val Loss: 0.6118
# Epoch 32, Train Loss: 0.3567, Val Loss: 0.5439
# Epoch 33, Train Loss: 0.3699, Val Loss: 0.5586
# Epoch 34, Train Loss: 0.3808, Val Loss: 0.6266
# Epoch 35, Train Loss: 0.3516, Val Loss: 0.5613
# Epoch 36, Train Loss: 0.3173, Val Loss: 0.5418
# Epoch 37, Train Loss: 0.2897, Val Loss: 0.5451
# Epoch 38, Train Loss: 0.2803, Val Loss: 0.5391
# Epoch 39, Train Loss: 0.2598, Val Loss: 0.5508
# Epoch 40, Train Loss: 0.2513, Val Loss: 0.5427
# Epoch 41, Train Loss: 0.2621, Val Loss: 0.5950
# Epoch 42, Train Loss: 0.2637, Val Loss: 0.5065
# Epoch 43, Train Loss: 0.2273, Val Loss: 0.5427
# Epoch 44, Train Loss: 0.2330, Val Loss: 0.5232
# Epoch 45, Train Loss: 0.2095, Val Loss: 0.5089
# Epoch 46, Train Loss: 0.2026, Val Loss: 0.5088
# ...
# Epoch 254, Train Loss: 0.0463, Val Loss: 0.3911
# Epoch 255, Train Loss: 0.0433, Val Loss: 0.4015
# Epoch 256, Train Loss: 0.0402, Val Loss: 0.3894
# Epoch 257, Train Loss: 0.0358, Val Loss: 0.3976
# Epoch 258, Train Loss: 0.0340, Val Loss: 0.3822
# Epoch 259, Train Loss: 0.0324, Val Loss: 0.3900
# Epoch 260, Train Loss: 0.0319, Val Loss: 0.3958
# Epoch 261, Train Loss: 0.0296, Val Loss: 0.3930
# Epoch 262, Train Loss: 0.0288, Val Loss: 0.3876
# Epoch 263, Train Loss: 0.0266, Val Loss: 0.3892
# Epoch 264, Train Loss: 0.0251, Val Loss: 0.3923
# Epoch 265, Train Loss: 0.0252, Val Loss: 0.3894
# Epoch 266, Train Loss: 0.0241, Val Loss: 0.3804
# Epoch 267, Train Loss: 0.0245, Val Loss: 0.3792
# Epoch 268, Train Loss: 0.0250, Val Loss: 0.3800
# Epoch 269, Train Loss: 0.0221, Val Loss: 0.3880
# Epoch 270, Train Loss: 0.0208, Val Loss: 0.3824
# Epoch 271, Train Loss: 0.0210, Val Loss: 0.3744
# Epoch 272, Train Loss: 0.0211, Val Loss: 0.3840
# Epoch 273, Train Loss: 0.0191, Val Loss: 0.3866
# Epoch 274, Train Loss: 0.0194, Val Loss: 0.3880
# Epoch 275, Train Loss: 0.0200, Val Loss: 0.3929
# Epoch 276, Train Loss: 0.0194, Val Loss: 0.3787
# Epoch 277, Train Loss: 0.0192, Val Loss: 0.3942
# Epoch 278, Train Loss: 0.0179, Val Loss: 0.3801
# Epoch 279, Train Loss: 0.0173, Val Loss: 0.3876
# Epoch 280, Train Loss: 0.0169, Val Loss: 0.3845
# Epoch 281, Train Loss: 0.0158, Val Loss: 0.3686
# Epoch 282, Train Loss: 0.0163, Val Loss: 0.3864
# Epoch 283, Train Loss: 0.0156, Val Loss: 0.3795
# Epoch 284, Train Loss: 0.0159, Val Loss: 0.3893
# Epoch 285, Train Loss: 0.0149, Val Loss: 0.3810
# Epoch 286, Train Loss: 0.0155, Val Loss: 0.3867
# Epoch 287, Train Loss: 0.0144, Val Loss: 0.3781
# Epoch 288, Train Loss: 0.0146, Val Loss: 0.3919
# Epoch 289, Train Loss: 0.0147, Val Loss: 0.3853
# Epoch 290, Train Loss: 0.0144, Val Loss: 0.3809
# Epoch 291, Train Loss: 0.0150, Val Loss: 0.3869
# Epoch 292, Train Loss: 0.0142, Val Loss: 0.3756
# Epoch 293, Train Loss: 0.0136, Val Loss: 0.3748
# Epoch 294, Train Loss: 0.0141, Val Loss: 0.3769
# Epoch 295, Train Loss: 0.0141, Val Loss: 0.3807
# Epoch 296, Train Loss: 0.0135, Val Loss: 0.3925
# Epoch 297, Train Loss: 0.0136, Val Loss: 0.3905
# Epoch 298, Train Loss: 0.0130, Val Loss: 0.3741
# Epoch 299, Train Loss: 0.0126, Val Loss: 0.3936
# Epoch 300, Train Loss: 0.0137, Val Loss: 0.3860
# Epoch 301, Train Loss: 0.0131, Val Loss: 0.3865
# Epoch 302, Train Loss: 0.0132, Val Loss: 0.3832
# Epoch 303, Train Loss: 0.0142, Val Loss: 0.3795
# Epoch 304, Train Loss: 0.0135, Val Loss: 0.3872
# Epoch 305, Train Loss: 0.0173, Val Loss: 0.3770
# Epoch 306, Train Loss: 0.0154, Val Loss: 0.3889
# Epoch 307, Train Loss: 0.0154, Val Loss: 0.4025
# Epoch 308, Train Loss: 0.0156, Val Loss: 0.3781
# Epoch 309, Train Loss: 0.0142, Val Loss: 0.4019
# Epoch 310, Train Loss: 0.0132, Val Loss: 0.3968
# Epoch 311, Train Loss: 0.0128, Val Loss: 0.3781
# Epoch 312, Train Loss: 0.0122, Val Loss: 0.3880
# Epoch 313, Train Loss: 0.0148, Val Loss: 0.3706
# Epoch 314, Train Loss: 0.0136, Val Loss: 0.3886
# Epoch 315, Train Loss: 0.0133, Val Loss: 0.3843
# Epoch 316, Train Loss: 0.0127, Val Loss: 0.3756
# Epoch 317, Train Loss: 0.0135, Val Loss: 0.3791
# Epoch 318, Train Loss: 0.0160, Val Loss: 0.3870
# Epoch 319, Train Loss: 0.0152, Val Loss: 0.3782
# Epoch 320, Train Loss: 0.0141, Val Loss: 0.3778
# Epoch 321, Train Loss: 0.0121, Val Loss: 0.3750
# Epoch 322, Train Loss: 0.0117, Val Loss: 0.3891
# Epoch 323, Train Loss: 0.0118, Val Loss: 0.3836
# Epoch 324, Train Loss: 0.0118, Val Loss: 0.3798
# Epoch 325, Train Loss: 0.0119, Val Loss: 0.3951
# Epoch 326, Train Loss: 0.0128, Val Loss: 0.3820
# Epoch 327, Train Loss: 0.0135, Val Loss: 0.3871
# Epoch 328, Train Loss: 0.0120, Val Loss: 0.3925
# Epoch 329, Train Loss: 0.0116, Val Loss: 0.3791
# Epoch 330, Train Loss: 0.0123, Val Loss: 0.3825
# Epoch 331, Train Loss: 0.0119, Val Loss: 0.3821
# Early stopping triggered.
# Top-12 markers Val Loss: 0.381138
#
#  Training with Top-14 markers: ['PSI', 'ASI', 'HEE', 'THAP', 'FMH', 'KNE', 'VMH', 'THAD', 'TIAP', 'THI', 'TOE', 'TIB', 'TIAD', 'ANK']
# Loaded 2336 samples (using 14 markers)
# Loaded 292 samples (using 14 markers)
# Epoch 1, Train Loss: 3.8660, Val Loss: 2.9678
# Epoch 2, Train Loss: 2.2914, Val Loss: 2.5582
# Epoch 3, Train Loss: 2.0323, Val Loss: 2.0423
# Epoch 4, Train Loss: 1.7902, Val Loss: 1.9192
# Epoch 5, Train Loss: 1.5158, Val Loss: 1.6185
# Epoch 6, Train Loss: 1.3525, Val Loss: 1.4992
# Epoch 7, Train Loss: 1.2377, Val Loss: 1.7250
# Epoch 8, Train Loss: 1.2390, Val Loss: 1.4210
# Epoch 9, Train Loss: 1.1489, Val Loss: 1.3946
# Epoch 10, Train Loss: 1.0327, Val Loss: 1.3135
# Epoch 11, Train Loss: 0.9697, Val Loss: 1.2081
# Epoch 12, Train Loss: 1.0096, Val Loss: 1.1392
# Epoch 13, Train Loss: 0.9270, Val Loss: 1.1081
# Epoch 14, Train Loss: 0.8293, Val Loss: 0.9278
# Epoch 15, Train Loss: 0.9148, Val Loss: 1.0363
# Epoch 16, Train Loss: 0.8974, Val Loss: 0.9449
# Epoch 17, Train Loss: 0.7378, Val Loss: 0.9359
# Epoch 18, Train Loss: 0.7814, Val Loss: 1.0181
# Epoch 19, Train Loss: 0.7039, Val Loss: 0.8196
# Epoch 20, Train Loss: 0.7614, Val Loss: 1.0047
# Epoch 21, Train Loss: 0.7484, Val Loss: 0.8022
# Epoch 22, Train Loss: 0.6143, Val Loss: 0.8281
# Epoch 23, Train Loss: 0.6594, Val Loss: 0.7873
# Epoch 24, Train Loss: 0.5524, Val Loss: 0.7681
# Epoch 25, Train Loss: 0.5378, Val Loss: 0.7590
# Epoch 26, Train Loss: 0.5277, Val Loss: 0.6591
# Epoch 27, Train Loss: 0.5011, Val Loss: 0.6333
# Epoch 28, Train Loss: 0.5180, Val Loss: 0.6328
# Epoch 29, Train Loss: 0.5416, Val Loss: 0.6964
# Epoch 30, Train Loss: 0.4957, Val Loss: 0.6336
# Epoch 31, Train Loss: 0.4287, Val Loss: 0.7494
# Epoch 32, Train Loss: 0.4354, Val Loss: 0.5719
# Epoch 33, Train Loss: 0.3837, Val Loss: 0.6947
# Epoch 34, Train Loss: 0.3834, Val Loss: 0.7842
# Epoch 35, Train Loss: 0.3734, Val Loss: 0.7498
# Epoch 36, Train Loss: 0.4296, Val Loss: 0.6059
# Epoch 37, Train Loss: 0.3953, Val Loss: 0.6250
# Epoch 38, Train Loss: 0.3456, Val Loss: 0.5759
# Epoch 39, Train Loss: 0.3358, Val Loss: 0.5352
# Epoch 40, Train Loss: 0.3261, Val Loss: 0.6268
# Epoch 41, Train Loss: 0.3222, Val Loss: 0.5887
# Epoch 42, Train Loss: 0.3158, Val Loss: 0.5187
# Epoch 43, Train Loss: 0.3179, Val Loss: 0.5934
# Epoch 44, Train Loss: 0.2807, Val Loss: 0.5310
# Epoch 45, Train Loss: 0.2875, Val Loss: 0.5914
# Epoch 46, Train Loss: 0.2603, Val Loss: 0.5416
# Epoch 47, Train Loss: 0.2458, Val Loss: 0.5058
# Epoch 48, Train Loss: 0.2316, Val Loss: 0.5204
# Epoch 49, Train Loss: 0.2398, Val Loss: 0.5218
# Epoch 50, Train Loss: 0.2328, Val Loss: 0.5144
# Epoch 51, Train Loss: 0.2141, Val Loss: 0.5235
# Epoch 52, Train Loss: 0.1945, Val Loss: 0.5242
# Epoch 53, Train Loss: 0.2236, Val Loss: 0.4944
# Epoch 54, Train Loss: 0.2791, Val Loss: 0.5176
# Epoch 55, Train Loss: 0.2163, Val Loss: 0.4861
# Epoch 56, Train Loss: 0.1735, Val Loss: 0.4570
# Epoch 57, Train Loss: 0.1629, Val Loss: 0.4477
# Epoch 58, Train Loss: 0.1587, Val Loss: 0.4478
# Epoch 59, Train Loss: 0.1578, Val Loss: 0.4902
# Epoch 60, Train Loss: 0.1877, Val Loss: 0.5120
# Epoch 61, Train Loss: 0.1860, Val Loss: 0.4827
# Epoch 62, Train Loss: 0.1691, Val Loss: 0.4667
# Epoch 63, Train Loss: 0.1722, Val Loss: 0.4422
# Epoch 64, Train Loss: 0.1578, Val Loss: 0.4909
# Epoch 65, Train Loss: 0.1542, Val Loss: 0.5378
# Epoch 66, Train Loss: 0.1652, Val Loss: 0.4557
# Epoch 67, Train Loss: 0.1303, Val Loss: 0.4463
# Epoch 68, Train Loss: 0.1126, Val Loss: 0.4659
# Epoch 69, Train Loss: 0.1110, Val Loss: 0.4405
# Epoch 70, Train Loss: 0.1122, Val Loss: 0.4377
# Epoch 71, Train Loss: 0.1168, Val Loss: 0.4223
# Epoch 72, Train Loss: 0.1108, Val Loss: 0.4390
# Epoch 73, Train Loss: 0.1356, Val Loss: 0.4930
# Epoch 74, Train Loss: 0.1166, Val Loss: 0.4210
# Epoch 75, Train Loss: 0.1066, Val Loss: 0.4507
# Epoch 76, Train Loss: 0.0974, Val Loss: 0.3969
# Epoch 77, Train Loss: 0.0894, Val Loss: 0.4239
# Epoch 78, Train Loss: 0.0891, Val Loss: 0.4603
# Epoch 79, Train Loss: 0.0910, Val Loss: 0.4152
# Epoch 80, Train Loss: 0.0891, Val Loss: 0.4358
# Epoch 81, Train Loss: 0.0827, Val Loss: 0.4436
# Epoch 82, Train Loss: 0.0957, Val Loss: 0.4799
# Epoch 83, Train Loss: 0.0923, Val Loss: 0.4122
# Epoch 84, Train Loss: 0.0848, Val Loss: 0.4237
# Epoch 85, Train Loss: 0.0801, Val Loss: 0.4483
# Epoch 86, Train Loss: 0.0882, Val Loss: 0.4377
# Epoch 87, Train Loss: 0.0805, Val Loss: 0.4279
# Epoch 88, Train Loss: 0.0834, Val Loss: 0.4138
# Epoch 89, Train Loss: 0.0773, Val Loss: 0.4210
# Epoch 90, Train Loss: 0.0793, Val Loss: 0.4221
# Epoch 91, Train Loss: 0.0746, Val Loss: 0.4104
# Epoch 92, Train Loss: 0.0643, Val Loss: 0.4058
# Epoch 93, Train Loss: 0.0690, Val Loss: 0.4060
# Epoch 94, Train Loss: 0.0893, Val Loss: 0.4484
# Epoch 95, Train Loss: 0.0774, Val Loss: 0.3989
# Epoch 96, Train Loss: 0.0666, Val Loss: 0.4176
# Epoch 97, Train Loss: 0.0809, Val Loss: 0.4122
# Epoch 98, Train Loss: 0.0637, Val Loss: 0.4153
# Epoch 99, Train Loss: 0.0578, Val Loss: 0.4111
# Epoch 100, Train Loss: 0.0555, Val Loss: 0.4033
# Epoch 101, Train Loss: 0.0516, Val Loss: 0.3960
# Epoch 102, Train Loss: 0.0498, Val Loss: 0.4012
# Epoch 103, Train Loss: 0.0472, Val Loss: 0.4025
# Epoch 104, Train Loss: 0.0461, Val Loss: 0.3976
# Epoch 105, Train Loss: 0.0532, Val Loss: 0.4234
# Epoch 106, Train Loss: 0.0458, Val Loss: 0.4013
# Epoch 107, Train Loss: 0.0502, Val Loss: 0.4073
# Epoch 108, Train Loss: 0.0512, Val Loss: 0.4055
# Epoch 109, Train Loss: 0.0524, Val Loss: 0.4004
# Epoch 110, Train Loss: 0.0479, Val Loss: 0.4320
# Epoch 111, Train Loss: 0.0460, Val Loss: 0.4201
# Epoch 112, Train Loss: 0.0490, Val Loss: 0.3851
# Epoch 113, Train Loss: 0.0532, Val Loss: 0.4045
# Epoch 114, Train Loss: 0.0482, Val Loss: 0.3962
# Epoch 115, Train Loss: 0.0445, Val Loss: 0.3908
# Epoch 116, Train Loss: 0.0403, Val Loss: 0.4101
# Epoch 117, Train Loss: 0.0398, Val Loss: 0.3962
# Epoch 118, Train Loss: 0.0407, Val Loss: 0.4170
# Epoch 119, Train Loss: 0.0534, Val Loss: 0.4030
# Epoch 120, Train Loss: 0.0499, Val Loss: 0.4139
# Epoch 121, Train Loss: 0.0464, Val Loss: 0.3954
# Epoch 122, Train Loss: 0.0448, Val Loss: 0.4182
# Epoch 123, Train Loss: 0.0398, Val Loss: 0.4028
# Epoch 124, Train Loss: 0.0372, Val Loss: 0.3943
# Epoch 125, Train Loss: 0.0364, Val Loss: 0.3905
# Epoch 126, Train Loss: 0.0390, Val Loss: 0.3899
# Epoch 127, Train Loss: 0.0446, Val Loss: 0.4182
# Epoch 128, Train Loss: 0.0457, Val Loss: 0.4013
# Epoch 129, Train Loss: 0.0360, Val Loss: 0.4037
# Epoch 130, Train Loss: 0.0371, Val Loss: 0.3934
# Epoch 131, Train Loss: 0.0494, Val Loss: 0.4043
# Epoch 132, Train Loss: 0.0429, Val Loss: 0.3904
# Epoch 133, Train Loss: 0.0371, Val Loss: 0.3752
# Epoch 134, Train Loss: 0.0313, Val Loss: 0.3859
# Epoch 135, Train Loss: 0.0294, Val Loss: 0.3783
# Epoch 136, Train Loss: 0.0348, Val Loss: 0.3707
# Epoch 137, Train Loss: 0.0364, Val Loss: 0.4092
# Epoch 138, Train Loss: 0.0341, Val Loss: 0.3968
# Epoch 139, Train Loss: 0.0326, Val Loss: 0.3853
# Epoch 140, Train Loss: 0.0331, Val Loss: 0.4021
# Epoch 141, Train Loss: 0.0344, Val Loss: 0.3899
# Epoch 142, Train Loss: 0.0317, Val Loss: 0.3800
# Epoch 143, Train Loss: 0.0310, Val Loss: 0.3800
# Epoch 144, Train Loss: 0.0353, Val Loss: 0.4008
# Epoch 145, Train Loss: 0.0351, Val Loss: 0.4035
# Epoch 146, Train Loss: 0.0406, Val Loss: 0.3817
# Epoch 147, Train Loss: 0.0486, Val Loss: 0.4078
# Epoch 148, Train Loss: 0.0773, Val Loss: 0.6360
# Epoch 149, Train Loss: 0.5188, Val Loss: 1.2413
# Epoch 150, Train Loss: 0.6798, Val Loss: 0.8526
# Epoch 151, Train Loss: 0.5149, Val Loss: 0.6395
# Epoch 152, Train Loss: 0.3810, Val Loss: 0.5769
# Epoch 153, Train Loss: 0.2526, Val Loss: 0.5209
# Epoch 154, Train Loss: 0.1682, Val Loss: 0.4604
# Epoch 155, Train Loss: 0.1179, Val Loss: 0.4587
# Epoch 156, Train Loss: 0.0869, Val Loss: 0.4404
# Epoch 157, Train Loss: 0.0690, Val Loss: 0.4244
# Epoch 158, Train Loss: 0.0595, Val Loss: 0.4105
# Epoch 159, Train Loss: 0.0559, Val Loss: 0.4115
# Epoch 160, Train Loss: 0.0490, Val Loss: 0.4448
# Epoch 161, Train Loss: 0.0458, Val Loss: 0.4248
# Epoch 162, Train Loss: 0.0403, Val Loss: 0.4312
# Epoch 163, Train Loss: 0.0369, Val Loss: 0.4153
# Epoch 164, Train Loss: 0.0350, Val Loss: 0.4204
# Epoch 165, Train Loss: 0.0346, Val Loss: 0.4148
# Epoch 166, Train Loss: 0.1079, Val Loss: 0.4580
# Epoch 167, Train Loss: 0.0775, Val Loss: 0.4312
# Epoch 168, Train Loss: 0.0509, Val Loss: 0.3770
# Epoch 169, Train Loss: 0.0368, Val Loss: 0.3986
# Epoch 170, Train Loss: 0.0350, Val Loss: 0.4048
# Epoch 171, Train Loss: 0.0299, Val Loss: 0.3979
# Epoch 172, Train Loss: 0.0268, Val Loss: 0.4004
# Epoch 173, Train Loss: 0.0269, Val Loss: 0.3925
# Epoch 174, Train Loss: 0.0259, Val Loss: 0.3890
# Epoch 175, Train Loss: 0.0240, Val Loss: 0.3814
# Epoch 176, Train Loss: 0.0239, Val Loss: 0.3764
# Epoch 177, Train Loss: 0.0239, Val Loss: 0.3827
# Epoch 178, Train Loss: 0.0215, Val Loss: 0.3928
# Epoch 179, Train Loss: 0.0208, Val Loss: 0.3775
# Epoch 180, Train Loss: 0.0219, Val Loss: 0.3991
# Epoch 181, Train Loss: 0.0213, Val Loss: 0.3634
# Epoch 182, Train Loss: 0.0214, Val Loss: 0.3791
# Epoch 183, Train Loss: 0.0209, Val Loss: 0.3776
# Epoch 184, Train Loss: 0.0190, Val Loss: 0.3861
# Epoch 185, Train Loss: 0.0209, Val Loss: 0.3739
# Epoch 186, Train Loss: 0.0230, Val Loss: 0.3799
# Epoch 187, Train Loss: 0.0217, Val Loss: 0.3776
# Epoch 188, Train Loss: 0.0183, Val Loss: 0.3841
# Epoch 189, Train Loss: 0.0172, Val Loss: 0.3900
# Epoch 190, Train Loss: 0.0173, Val Loss: 0.3713
# Epoch 191, Train Loss: 0.0177, Val Loss: 0.3928
# Epoch 192, Train Loss: 0.0173, Val Loss: 0.3836
# Epoch 193, Train Loss: 0.0352, Val Loss: 0.4107
# Epoch 194, Train Loss: 0.0296, Val Loss: 0.3712
# Epoch 195, Train Loss: 0.0233, Val Loss: 0.3633
# Epoch 196, Train Loss: 0.0200, Val Loss: 0.3591
# Epoch 197, Train Loss: 0.0203, Val Loss: 0.3621
# Epoch 198, Train Loss: 0.0668, Val Loss: 0.4313
# Epoch 199, Train Loss: 0.0764, Val Loss: 0.4246
# Epoch 200, Train Loss: 0.0495, Val Loss: 0.4389
# Epoch 201, Train Loss: 0.0401, Val Loss: 0.4211
# Epoch 202, Train Loss: 0.0270, Val Loss: 0.3862
# Epoch 203, Train Loss: 0.0231, Val Loss: 0.3905
# Epoch 204, Train Loss: 0.0197, Val Loss: 0.3841
# Epoch 205, Train Loss: 0.0177, Val Loss: 0.3912
# Epoch 206, Train Loss: 0.0174, Val Loss: 0.4195
# Epoch 207, Train Loss: 0.0167, Val Loss: 0.3950
# Epoch 208, Train Loss: 0.0162, Val Loss: 0.3691
# Epoch 209, Train Loss: 0.0158, Val Loss: 0.3744
# Epoch 210, Train Loss: 0.0165, Val Loss: 0.4088
# Epoch 211, Train Loss: 0.0258, Val Loss: 0.3813
# Epoch 212, Train Loss: 0.0195, Val Loss: 0.3681
# Epoch 213, Train Loss: 0.0167, Val Loss: 0.3754
# Epoch 214, Train Loss: 0.0167, Val Loss: 0.4067
# Epoch 215, Train Loss: 0.0163, Val Loss: 0.3973
# Epoch 216, Train Loss: 0.0145, Val Loss: 0.3782
# Epoch 217, Train Loss: 0.0139, Val Loss: 0.3923
# Epoch 218, Train Loss: 0.0143, Val Loss: 0.3779
# Epoch 219, Train Loss: 0.0134, Val Loss: 0.3780
# Epoch 220, Train Loss: 0.0153, Val Loss: 0.3890
# Epoch 221, Train Loss: 0.0153, Val Loss: 0.3902
# Epoch 222, Train Loss: 0.0160, Val Loss: 0.3768
# Epoch 223, Train Loss: 0.0137, Val Loss: 0.4012
# Epoch 224, Train Loss: 0.0141, Val Loss: 0.3713
# Epoch 225, Train Loss: 0.0146, Val Loss: 0.3856
# Epoch 226, Train Loss: 0.0158, Val Loss: 0.3791
# Epoch 227, Train Loss: 0.0166, Val Loss: 0.3750
# Epoch 228, Train Loss: 0.0196, Val Loss: 0.3929
# Epoch 229, Train Loss: 0.0215, Val Loss: 0.3910
# Epoch 230, Train Loss: 0.0173, Val Loss: 0.3848
# Epoch 231, Train Loss: 0.0181, Val Loss: 0.3892
# Epoch 232, Train Loss: 0.0161, Val Loss: 0.3946
# Epoch 233, Train Loss: 0.0151, Val Loss: 0.3592
# Epoch 234, Train Loss: 0.0193, Val Loss: 0.3756
# Epoch 235, Train Loss: 0.0201, Val Loss: 0.3759
# Epoch 236, Train Loss: 0.0226, Val Loss: 0.3679
# Epoch 237, Train Loss: 0.0183, Val Loss: 0.3790
# Epoch 238, Train Loss: 0.0156, Val Loss: 0.3776
# Epoch 239, Train Loss: 0.0133, Val Loss: 0.3847
# Epoch 240, Train Loss: 0.0125, Val Loss: 0.3709
# Epoch 241, Train Loss: 0.0131, Val Loss: 0.3683
# Epoch 242, Train Loss: 0.0127, Val Loss: 0.3627
# Epoch 243, Train Loss: 0.0125, Val Loss: 0.3776
# Epoch 244, Train Loss: 0.0119, Val Loss: 0.3781
# Epoch 245, Train Loss: 0.0131, Val Loss: 0.4071
# Epoch 246, Train Loss: 0.0123, Val Loss: 0.3964
# Early stopping triggered.
# Top-14 markers Val Loss: 0.368786
#
#  Best marker combination:
# Top-6 markers: ['PSI', 'ASI', 'HEE', 'THAP', 'FMH', 'KNE']
# Val Loss: 0.364483
#  Best model saved to: best_marker_combination2.pth
# Loaded 292 samples (using 6 markers)
# Test MSE: 0.505067

# %%
# ========== Visualize Average KAM Curves ==========

# Function to plot average predicted vs. ground truth KAM curves
def plot_average_kam_curve(model, dataset, device='cuda', save_path=None, show=True):
    import matplotlib.pyplot as plt

    model = model.to(device)
    model.eval()

    all_true = []
    all_pred = []

    max_length = 0
    for idx in range(len(dataset)):
        sample = dataset[idx]
        x = sample['input'].unsqueeze(0).to(device)
        y = sample['target'].unsqueeze(0).to(device)
        T = x.shape[1]
        mask = torch.ones((1, T), dtype=torch.bool).to(device)

        with torch.no_grad():
            pred = model(x, mask)

        true_kam = y.squeeze(0).cpu().numpy()
        pred_kam = pred.squeeze(0).cpu().numpy()
        length = min(len(true_kam), len(pred_kam))
        max_length = max(max_length, length)

        all_true.append(true_kam[:length])
        all_pred.append(pred_kam[:length])

    # Pad all sequences to the maximum length with NaN
    def pad_with_nan(seq_list, max_len):
        return np.array([
            np.pad(seq, (0, max_len - len(seq)), constant_values=np.nan)
            for seq in seq_list
        ])

    all_true_padded = pad_with_nan(all_true, max_length)
    all_pred_padded = pad_with_nan(all_pred, max_length)

    # Compute mean curves over valid (non-NaN) values
    mean_true_curve = np.nanmean(all_true_padded, axis=0)
    mean_pred_curve = np.nanmean(all_pred_padded, axis=0)

    # Plot the mean curves
    plt.figure(figsize=(10, 5))
    plt.plot(mean_true_curve, label='Mean Ground Truth', linewidth=2)
    plt.plot(mean_pred_curve, label='Mean Prediction', linestyle='--')
    plt.xlabel('Frame')
    plt.ylabel('KAM')
    plt.title('CNN+LSTM Mean KAM Curve Across All Samples')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()

    if save_path:
        plt.savefig(save_path)
        plt.close()
    elif show:
        plt.show()

# %%
# Plot the average KAM curve for the test set
plot_average_kam_curve(model, test_set, device='cuda')

# %%
# ========== Extract Peak KAM Metrics ==========

# Function to extract peak KAM values and their prediction errors
def extract_peak_kam_metrics(model, dataset, save_csv_path='results/peak_kam_summary.csv', device=device):
    model = model.to(device)
    model.eval()
    records = []

    for idx in range(len(dataset)):
        sample = dataset[idx]
        x = sample['input'].unsqueeze(0).to(device)      # (1, T, N, D)
        y = sample['target'].unsqueeze(0).to(device)     # (1, T)
        T = x.shape[1]
        mask = torch.ones((1, T), dtype=torch.bool).to(device)
        filename = sample['filename']

        with torch.no_grad():
            pred = model(x, mask)  # (1, T)

        # Extract KAM values
        pred_kam = pred.squeeze(0).cpu().numpy()
        true_kam = y.squeeze(0).cpu().numpy()

        # Split sequence into two halves to identify the first and second peaks
        mid = T // 2
        true_kam1 = np.max(true_kam[:mid]) if mid > 0 else np.nan
        true_kam2 = np.max(true_kam[mid:]) if mid < T else np.nan
        pred_kam1 = np.max(pred_kam[:mid]) if mid > 0 else np.nan
        pred_kam2 = np.max(pred_kam[mid:]) if mid < T else np.nan

        records.append({
            'n': filename,
            'peak KAM1 Actual': true_kam1,
            'peak KAM1 Predict': pred_kam1,
            'peak KAM2 Actual': true_kam2,
            'peak KAM2 Predict': pred_kam2,
        })

    # Save results to a CSV file
    df = pd.DataFrame(records)
    df.to_csv(save_csv_path, index=False)
    print(f"{save_csv_path}")
    return df

# %%
from numpy import mean, std

# Calculate and save peak KAM metrics
df = extract_peak_kam_metrics(model, test_set, device=device)

# Compute and print Mean Squared Errors (MSE) for the first and second peaks
kam1_mse = mean((df['peak KAM1 Actual'] - df['peak KAM1 Predict'])**2)
kam2_mse = mean((df['peak KAM2 Actual'] - df['peak KAM2 Predict'])**2)

print(f"Peak KAM1 MSE  → Mean = {kam1_mse:.6f}")
print(f"Peak KAM2 MSE  → Mean = {kam2_mse:.6f}")
# Out:
# results/peak_kam_summary.csv
# Peak KAM1 MSE  → Mean = 0.834704
# Peak KAM2 MSE  → Mean = 0.673467
